# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from PIL import Image
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import csv
from sklearn.model_selection import train_test_split
import datetime

# %%
def parse_data_from_csv(file_path, reshape = (None, None)):

  with open(file_path) as file:
    ### START CODE HERE

    # Use csv.reader, passing in the appropriate delimiter
    # Remember that csv.reader can be iterated and returns one line in each iteration
    labels = []
    reviews = []

    csv_reader = csv.reader(file, delimiter='\n')
    next(csv_reader)
    for row in csv_reader:
        try:
            row = row[0].split(',')
            labels.append(int(row[-1]))
            reviews.append(row[-2])
        except:
            print(f' exception during: {row}')

    labels = np.array(labels, dtype = np.float32)
    reviews = np.array(reviews)

    ### END CODE HERE

    return reviews, labels

# %%
def split_dataset(images, labels, train_split, shuffle = True):
    train_images, validation_images, train_labels, validation_labels = train_test_split(images, labels , train_size= train_split, stratify=labels, shuffle=True)
    return train_images, validation_images, train_labels, validation_labels

# %%
file_path = './train.csv'
reviews, labels = parse_data_from_csv(file_path)
# Out:
#  exception during: ['61', 'ablaze', '', '"on the outside you\'re ablaze and alive']
#  exception during: ['74', 'ablaze', 'India', '"Man wife get six years jail for setting ablaze niece']
#  exception during: ['86', 'ablaze', 'Inang Pamantasan', '"Progressive greetings!']
#  exception during: []
#  exception during: ['117', 'accident', '', '"mom: \'we didn\'t get home as fast as we wished\' ']
#  exception during: ["me: 'why is that?'"]
#  exception during: ['149', 'aftershock', '304', '"\'The man who can drive himself further once the effort gets painful is the man who will win.\' ']
#  exception during: ['178', 'aftershock', 'United States', '"&gt;&gt; $15 Aftershock : Protect Yourself and Profit in the Next Global Financial... ##book http://t.co/f6ntUc734Z']
#  exception during: ['218', 'airplane%20accident', '', '"This is unbelievably insane.']
#  exception during: ['232', 'airplane%20accident', 'Havenford', '"+ Nicole Fletcher one of a victim of crashed airplane few times ago. ']
#  exception during: []
#  exception during: ["The accident left a little bit trauma for her. Although she's "]
#  exception during: []
#  exception during: ['237', 'airplane%20accident', '92', '"#OMG! I don\'t believe this. #RIP bro']
#  exception during: ['322', 'annihilated', 'London', '"During the 1960s the oryx a symbol of the Arabian Peninsula were annihilated by hunters. ']
#  exception during: ['340', 'annihilated', 'Swaning Around', '"ANNIHILATED IN DAMASCUS: SYRIAN ARMY GRINDS \x89Û÷ALLOOSH AND HIS GANG INTO THE MANURE PILE']
#  exception during: ['371', 'annihilation', 'Republic of Texas', '"The annihilation of Jeb Christie &amp; Kasich is less than 24 hours away..']
#  exception during: ['419', 'apocalypse', '', '"RT: Our_Mother_Mary: Short Reading']
#  exception during: []
#  exception during: ['Apocalypse 21:1023 ']
#  exception during: []
#  exception during: ['443', 'apocalypse', '', '"Short Reading']
#  exception during: []
#  exception during: ['Apocalypse 21:1023 ']
#  exception during: []
#  exception during: ['456', 'armageddon', 'probably the strip club', '"//im gonna beat armageddon as Hsu Hao ????']
#  exception during: ['468', 'armageddon', '"Rotterdam', ' Zuid-Holland"', '"@AberdeenFC @AberdeenFanPage ']
#  exception during: []
#  exception during: ['Good luck to the ?????? tomorrow night ']
#  exception during: []
#  exception during: ['Get some coefficient points plz ']
#  exception during: ['471', 'armageddon', '"Florida', ' USA"', '"Vladimir Putin Issues Major Warning But Is It Too Late To Escape Armageddon?']
#  exception during: ['481', 'armageddon', '"Castaic', ' CA"', '"Armageddon averted by El Patron']
#  exception during: ['495', 'armageddon', 'Perthshire ', '"Well done Celtic Fingers crossed for Aberdeen tomorrow night! ']
#  exception during: ['506', 'army', 'cyprus', '"Build your own kingdom and lead your army to victory! https://youtu.']
#  exception during: []
#  exception during: ['520', 'army', 'Pakistan', '".: .: .: .: .: .: .: .: .: .: .: .: .: .: .: .: .: .: .: .: .: RT DrAyesha4: #IndiaKoMunTorJawabDo']
#  exception during: []
#  exception during: ['524', 'army', 'Campinas Sp', '"You da One ']
#  exception during: []
#  exception during: ['568', 'arson', 'bajaur', '"After death of Palestinian toddler in arson']
#  exception during: ['652', 'attack', 'Location', '"BREAKING: Terror Attack On']
#  exception during: ['672', 'attack', '"Scotland', ' United Kingdom"', '"\'Left hand side of a diamond is a graveyard shift have to attack and defend\'']
#  exception during: ['800', 'battle', 'NYC', '"YA BOY CLIP VS 4KUS FULL BATTLE']
#  exception during: []
#  exception during: ['@15MofeRadio @Heavybag201 @battle_dom @QOTRING @BattleRapChris @Hughes1128 ']
#  exception during: []
#  exception during: ['803', 'battle', '', '"#Tb #throwback ??']
#  exception during: []
#  exception during: ['826', 'battle', 'Australia', '"#LonePine remembered around Australia as \'descendants\' grow via @666canberra #Gallipoli #WW1']
#  exception during: ['860', 'bioterror', '"Pelham', ' AL"', '"Thank you @FedEx for no longer shipping live microbes for the Department of Defense']
#  exception during: []
#  exception during: ['891', 'bioterrorism', '', '"Creation of AI']
#  exception during: ['Climate change']
#  exception during: ['Bioterrorism']
#  exception during: ['Mass automation of workforce']
#  exception during: ['Contact with other life']
#  exception during: ['Wealth inequality']
#  exception during: []
#  exception during: ['974', 'blaze', 'SOUTHERN CALIFORNIA DESERT', '"3 Bedrooms 1 Baths for sale in 29 Palms CA. (http://t.co/QMS8RRESsd)']
#  exception during: ['983', 'blazing', '"Intramuros', ' Manila"', '"Come and join us Tomorrow!']
#  exception during: ['993', 'blazing', 'Between the worlds ', '"I\'m the only weapons master here! Let\'s go in guns blazing!']
#  exception during: ['997', 'blazing', 'Your screen', '"S3XLEAK!!!']
#  exception during: ['1015', 'blazing', 'Everywhere', '"**Let - Me - Be - Your - Hot - Blazing - Fantasy**  ']
#  exception during: ['1057', 'bleeding', '', '"I\'ve been bleeding in your silence ']
#  exception during: ['1078', 'bleeding', '"Alicante', ' Valencia"', '"they say bad things happen for a reason']
#  exception during: ['1088', 'blew%20up', '', '"i hate people who tweet \'receipts\' but KNOW its wrong']
#  exception during: []
#  exception during: ["but they wont take it down bc it 'blew up'"]
#  exception during: ['1120', 'blew%20up', '"Vancouver', ' BC."', '"Because you watched: Honey I Blew up the Economy']
#  exception during: []
#  exception during: ['We Recommend : The Conservative Shoppe of Horrors']
#  exception during: []
#  exception during: ['1130', 'blight', 'Kama | 18 | France ', '"@DaMidnighter theres actually a theory out there that the magisters arent the only reason for the blight']
#  exception during: ['1152', 'blight', '"Colombo', 'Sri Lanka."', '"Releases on the planing level -']
#  exception during: []
#  exception during: ["1. Constellation - Blight on Gaia - iClown's Drumstep Remix"]
#  exception during: ['1175', 'blight', '"Detroit', ' MI', ' United States"', '"Article by Michael Jackman at Metro Times Detroit:']
#  exception during: ['1226', 'blizzard', '', '"Someone walk with me to DQ ??']
#  exception during: ['1308', 'bloody', '', '"All I need in this life of sin']
#  exception during: ['Is just me and my girlfriend']
#  exception during: ['Down to ride till the bloody end']
#  exception during: ['1327', 'bloody', 'AUS', '"Marlon Williams &gt; Elvis Presley &gt; Marlon Williams &gt; Steel Panther. ']
#  exception during: []
#  exception during: ['1334', 'blown%20up', 'Oklahoma', '"@ManUtd @EmilymcfcHeslop ']
#  exception during: []
#  exception during: ['Wow just wow! ']
#  exception during: []
#  exception during: ['1349', 'blown%20up', 'Cobblestone', '"\'If a truckload of soldiers will be blown up nobody panics but when one little lion dies everyone loses their mind\'']
#  exception during: ['1350', 'blown%20up', '"ÌÏT: 30.307558', '-81.403118"', '"HEY LOOK!!!  Kash\'s Foundation Live for Today got blown up on People Magazine\'s website!!  ']
#  exception during: []
#  exception during: ['1356', 'blown%20up', 'kisumu', '"LONER DIARIES.']
#  exception during: []
#  exception during: ['The patterns  on the sand']
#  exception during: ['May have been blown away.']
#  exception during: ['The photos in twos']
#  exception during: ['1415', 'body%20bag', '', '"#handbag #fashion #style http://t.co/hPd3SNM6oy Vintage Coach Purse Camera Bag Cross Body #9973']
#  exception during: []
#  exception during: ['$16.99 (0 Bids)']
#  exception during: ['1506', 'body%20bags', '', '"I love The body shop\x89Ûªs bags??']
#  exception during: []
#  exception during: ['1530', 'bomb', '"Aarhus', ' Central Jutland"', '"Listen to this hit song. A summer Bomb full of positive energy and youth']
#  exception during: ['Did you like it?']
#  exception during: ['https://t.co/2LiWkJybE9 ']
#  exception during: ['1574', 'bomb', '"Odawara', ' Japan"', '"Oops.']
#  exception during: ['H bomb lost 70 miles off the Okinawan coast.']
#  exception during: ['Fell off the ship 1965.']
#  exception during: ['1600', 'bombed', '??', '"\'the third generation atomic bombed survivor\' Photo exhibition 11:00 to 18:00 8/6. ']
#  exception during: ['1638', 'bombing', '', '"The only country claiming the moral high ground is the only one to have dropped atomic bombs. #Hiroshima #BanTheBomb']
#  exception during: ['1662', 'bombing', 'North East USA', '"What it was like to survive the atomic bombing of Hiroshima']
#  exception during: ['1673', 'bridge%20collapse', '', '"Australia\'s Ashes disaster - how the collapse unfolded at Trent Bridge... http://t.co/Dq3ddGvgBF']
#  exception during: ['1739', 'buildings%20burning', 'Ziam af ', '"Messi: has tattoos so he can\'t donate blood']
#  exception during: ['1762', 'buildings%20burning', '"England', ' United Kingdom"', '"Must get hot in burning buildings']
#  exception during: []
#  exception during: ['1770', 'buildings%20burning', '', '"http://t.co/WRB7Xd8W5y']
#  exception during: ['CROYDON RIOTS- The Next Day: Burning Buildings in High Street &amp; crowds at Reeves Corner']
#  exception during: ['Croydonization']
#  exception during: ['1787', 'buildings%20on%20fire', 'taken by piper curda', '"someone: mentions gansey on fire']
#  exception during: ['1833', 'burned', '"Port Charlotte', ' FL"', '"Always look for the silver lining!  ']
#  exception during: []
#  exception during: ['My barn having burned to the ground']
#  exception during: ['I can now see the moon.']
#  exception during: ['1856', 'burned', '', '"@kennethbauer_ more like coffee and noodles ']
#  exception during: []
#  exception during: ['1961', 'burning%20buildings', '"Copenhagen', ' Capital Region of Denmark"', '"dog rendered a kitten from burning buildings']
#  exception during: ['1965', 'burning%20buildings', 'seattle grace mercy death', '"\'i never understood guys who wanted to run into burning buildings.\'']
#  exception during: ["'you chase murderers.'"]
#  exception during: ['1967', 'burning%20buildings', '"Tucson', ' Arizona "', '"You picture buildings burning to the ground from the basement to the streetlight. ']
#  exception during: []
#  exception during: ["I'm not your drinking problem"]
#  exception during: ['2010', 'casualties', '', '"??']
#  exception during: ['2019', 'casualties', '"Phoenix', ' AZ"', '"Afghanistan: U.N. Reports \'Record-High Levels\' of Civilian Casualties']
#  exception during: ['    ']
#  exception during: ['2035', 'casualties', '', '"Students at Sutherland remember Australian casualties at Lone Pine Gallipoli']
#  exception during: ['2038', 'casualties', '50% Queanbeyan - 50% Sydney', '"@FlyOpineMonkey You mean Olympic ;-) ']
#  exception during: ['Also its follow-up for Honshu Operation Coronet. ']
#  exception during: ['2047', 'casualties', 'everywhere ', '"Revise the Death to America scenario? ']
#  exception during: []
#  exception during: ['2082', 'casualty', 'LIVERPOOL', '"You can\'t watch \'Home Alone 2\' without telling your kids ']
#  exception during: ["'she used to be on Casualty'. "]
#  exception during: ['2142', 'catastrophe', "Lytham St Anne's ", '"Oh my god that\x89Ûªs the biggest #gbbo catastrophe I have EVER seen. ']
#  exception during: []
#  exception during: ['2158', 'catastrophe', '"Lima', ' PerÌ¼"', '"Britney Spears &gt; Vegas!! I missed you so much! ?? Can\x89Ûªt wait for the show tonight ?? #PieceOfMe ']
#  exception during: []
#  exception during: ['2172', 'catastrophic', '"Buxton', ' Venice', ' and Nottingham"', '"\'Invading Iraq was a catastrophic mistake\'.']
#  exception during: []
#  exception during: ['Diplomacy needs to replace constant threat of war by US and Israel:']
#  exception during: []
#  exception during: ['2203', 'catastrophic', '', '"Excited not only about the next 6 years of school and ensuing student debt but also catastrophic climate change in my lifetime   ']
#  exception during: []
#  exception during: ['2244', 'chemical%20emergency', '', '"Please stand up for bees against profit-hungry chemical companies. Keep the ban &amp; #Savebees ']
#  exception during: ['Sign the petition now:']
#  exception during: ['2251', 'chemical%20emergency', '"Orbost', ' Victoria', ' Australia"', '"Lindenow: 3:15pm']
#  exception during: ['2258', 'cliff%20fall', '"London', ' England"', '"NEWS FLASH!  Any decent billers been promoted to \'manager\'? If so let me know as I want to watch your billings fall off a cliff.']
#  exception during: ['2297', 'cliff%20fall', "DRAW A CIRCLE THAT'S THE EARTH", '"*Jumps off of a cliff while drinking tea*']
#  exception during: []
#  exception during: ['2339', 'collapse', '', '"Spot fixing/match fixing ..anyone???']
#  exception during: ['2350', 'collapse', 'Behind The Obama Curtain', '"Greece\'s tax revenues collapse as debt crisis continues']
#  exception during: ['2451', 'collide', '', '"Secrets of the world collide but i leave the past behind ']
#  exception during: ['2460', 'collided', '"-6.152261', '106.775995"', '"When love and hate collided part II']
#  exception during: ['Lanjut dirumah...']
#  exception during: []
#  exception during: ['2462', 'collided', "@protectingtitan's side.", '"--thus making @FemaleGilgamesh\'s assault useless.']
#  exception during: ['The spears collided with the dark force however did not penetrate.']
#  exception during: []
#  exception during: ['2496', 'collided', 'See the barn of bleakness', '"OMG OMG OMG #JustinBieber and #HarryStyles have collided in a nuclear accident at #Cern ^oo^']
#  exception during: []
#  exception during: ['2538', 'collision', '', '"my favorite lady came to our volunteer meeting']
#  exception during: ['2571', 'crash', '"Melbourne', ' Australia"', '"#INCIDENT']
#  exception during: ['2587', 'crash', '', '"??One night and we\'re gonna come and crash the party']
#  exception during: ['2619', 'crashed', '', '"My iPod crashed..... ']
#  exception during: ['#WeLoveYouLouis ']
#  exception during: ['2647', 'crashed', '', '"f496D mhtw4fnet']
#  exception during: []
#  exception during: ['2744', 'crushed', 'Trinidad & Tobago', '"Disillusioned lead character ']
#  exception during: ['Check']
#  exception during: ['Happy go lucky free spirit girl']
#  exception during: ['Check']
#  exception during: ['Dream life crushed']
#  exception during: ['Check']
#  exception during: ['Great music']
#  exception during: ['Check']
#  exception during: ['2759', 'curfew', '"State College', ' PA"', '"Is there a night curfew on campus?']
#  exception during: []
#  exception during: ['2773', 'curfew', 'urÌ£nus', '"It was past curfew']
#  exception during: ['2808', 'cyclone', 'USA', '"#Camera #Art #Photography http://t.co/TJGxDc3D5p #0215 New BoltåÊCyclone DR PP-400DR Dual Outlet Power PackåÊFor External Camera Flash']
#  exception during: []
#  exception during: ['2813', 'cyclone', 'Republic of the Philippines', '"A new tropical cyclone is forming near Guam.']
#  exception during: []
#  exception during: ['2821', 'cyclone', 'Philippines ', '"SEVERE WEATHER BULLETIN No. 5']
#  exception during: ['FOR: TYPHOON \x89ÛÏ#HannaPH\x89Û\x9d (SOUDELOR)']
#  exception during: ['TROPICAL CYCLONE: WARNING']
#  exception during: []
#  exception during: ['2827', 'cyclone', '"Quezon City', ' Philippines"', '"SEVERE WEATHER BULLETIN #6']
#  exception during: ["TROPICAL CYCLONE WARNING: TYPHOON 'HANNA' "]
#  exception during: ['2828', 'cyclone', 'Geneva', '"Back to the future in #Vanuatu how Cyclone Pam has encouraged traditional ways of living:']
#  exception during: ['2829', 'cyclone', '"Hartford', '  connecticut"', '"Bank manager asks Tom in an interview: \'What is cyclone\'']
#  exception during: ['2839', 'cyclone', '', '"HIS MAJESTY EMPEROR SALMAN KHAN\'S UNSTOPPABLE CYCLONE OF ENTERTAINMENT HUMANITY']
#  exception during: ['BAJRANGI BHAIJAAN CREATING HISTORY EVERYWHERE ']
#  exception during: ['2844', 'cyclone', 'Vilnius', '"Some drugs and alcohol in Jackson Vroman house.']
#  exception during: []
#  exception during: ['2846', 'cyclone', 'Geneva', '"Blending the old with the new in #Vanuatu to prepare for future emergencies: ']
#  exception during: ['2871', 'damage', 'http://twitch.tv/jcmonkey', '"@Drothvader @CM_Nevalistis you can keep this please!!!!! Arachys']
#  exception during: ['2888', 'damage', '', '"New post on my blog: http://t.co/Avu9b4k2rv ']
#  exception during: ['thesensualeye:']
#  exception during: []
#  exception during: ['Model: Cam Damage']
#  exception during: []
#  exception during: ['Toronto Apr 2014']
#  exception during: []
#  exception during: ['2890', 'damage', '', '"Devil May Cry 4 Special Edition Vergil Vs Agnus [Window] Mission 6 - DMD - No Damage By LeedStraiF']
#  exception during: ['2899', 'damage', 'USAoV', '"lmao fuckboy changed his @ for damage control']
#  exception during: ['2921', 'danger', 'Atlanta Georgia ', '"@therealRITTZ #FETTILOOTCH IS #SLANGLUCCI OPPRESSIONS GREATEST DANGER COMING SOON THE ALBUM ']
#  exception during: ['2929', 'danger', 'Atlanta Georgia ', '"@bluebirddenver #FETTILOOTCH IS #SLANGLUCCI OPPRESSIONS GREATEST DANGER COMING SOON THE ALBUM ']
#  exception during: ['2935', 'danger', 'Atlanta Georgia ', '"@RemainOnTop #FETTILOOTCH IS #SLANGLUCCI OPPRESSIONS GREATEST DANGER COMING SOON THE ALBUM ']
#  exception during: ['2936', 'danger', 'Atlanta Georgia ', '"@nuggets #FETTILOOTCH IS #SLANGLUCCI OPPRESSIONS GREATEST DANGER COMING SOON THE ALBUM ']
#  exception during: ['2941', 'danger', 'Instagram: trillrebel_', '"Guns are for protection.. ']
#  exception during: ['2959', 'dead', 'London', '"remember that time goku gave life to a dead birb ']
#  exception during: ['2974', 'dead', 'somewhere in Portugal', '"If it\x89Ûªs a war you came to see you will never see a waved white flag in front me.']
#  exception during: ['3025', 'death', '', '"https://t.co/eCMUjkKqX1 @ArianaGrande @ScreamQueens ']
#  exception during: ['3030', 'death', '', '"https://t.co/oIfN28HpCS @ArianaGrande @ScreamQueens ']
#  exception during: ['3056', 'deaths', '"Mooseknuckle', ' Maine"', '"\x89ÛÏ@LOLGOP: 2.2 cases of voter fraud a year. ']
#  exception during: ['WE NEED NEW LAWS!']
#  exception during: []
#  exception during: ['83 gun deaths a day. ']
#  exception during: ['WHO ACTUALLY FOLLOWS LAWS AMIRITE?']
#  exception during: []
#  exception during: ['3072', 'deaths', 'Lagos', '"[Comment] Deaths of older children: what do the data tell #US? http://t.co/p8Yr2po6Jn']
#  exception during: ['3075', 'deaths', 'Your screen', '"real magic in real life:']
#  exception during: []
#  exception during: ['3086', 'deaths', 'Blackpool', '"Cancers equate for around 25% of all deaths in #Blackpool. ']
#  exception during: []
#  exception during: ['Kowing the signs could save your life: http://t.co/5lNIdvoBff']
#  exception during: ['3093', 'deaths', 'Blackpool', '"Cancers equate for around 25% of all deaths in #Blackpool. ']
#  exception during: []
#  exception during: ['Kowing the signs could save your life: http://t.co/11dVqjVXPo']
#  exception during: ['3124', 'debris', '"Hamilton', ' Ontario Canada"', '"Malaysia seem more certain than France.']
#  exception during: []
#  exception during: ['3280', 'demolish', 'MAD as Hell', '"RT AbbsWinston: #Zionist #Terrorist demolish 18 #Palestinian structures in Jordan Valley http://t.co/rg3BndKXjX']
#  exception during: ['3302', 'demolish', 'Bagalkote Karnataka ', '"#charminar demolish if it in falling state anyway take engineers opinion']
#  exception during: ['3309', 'demolished', '"NH via Boston', ' MA"', '".']
#  exception during: ['3364', 'demolition', '"Murray Hill', ' New Jersey"', '"Remaining Sections Of Greystone Psychiatric Hospital Under Demolition ']
#  exception during: ['3391', 'demolition', '"Funtua', ' Nigeria"', '"Kaduna Begins Demolition Of Buildings On Govt School Lands']
#  exception during: ['3475', 'derailed', '"Enterprise', ' Alabama"', '"Has #IdentityTheft Derailed Your #TaxReturn? ']
#  exception during: ['8 Steps for Cleaning Up an  #IdentityTheft Train Wreck. #CRI']
#  exception during: ['3498', 'derailed', 'Texas-USA\x89ã¢ ?', '"CNN News August 5 2015 Two trains derailed amid floods ...']
#  exception during: ['3509', 'derailment', 'Mumbai', '"MP trains derailment: \x89Û÷It\x89Ûªs the freakiest of freak accidents\x89Ûª: ']
#  exception during: []
#  exception during: ['3519', 'derailment', '', '"MP train derailment: Village youth saved many lives']
#  exception during: ['3523', 'derailment', 'Chicagoland', '"CHICAGO FD']
#  exception during: ['STILL &amp; BOX ALARM/EMS PLAN I ']
#  exception during: [' 61ST &amp; CALUMET FOR THE EL TRAIN DERAILMENT']
#  exception during: ['3555', 'desolate', 'United Kingdom', '"\'What we perceive burns faintly like a sputtering candle before the vast desolate glacier of Eternity\'']
#  exception during: []
#  exception during: ['3610', 'desolation', 'Lagos Nigeria', '"Isai 60:1; Psm 138:8']
#  exception during: ['3628', 'desolation', '"Austin', ' TX"', '"@nikostar :(']
#  exception during: ['3640', 'desolation', '"Quilmes ', ' Arg"', '"This desperation dislocation']
#  exception during: ['Separation condemnation']
#  exception during: ['Revelation in temptation']
#  exception during: ['Isolation desolation']
#  exception during: ['3646', 'desolation', 'Chile', '"Fear and panic in the air']
#  exception during: ['I want to be free']
#  exception during: ['From desolation and despair']
#  exception during: ['3652', 'destroy', '"San Diego', ' CA"', '"Plot']
#  exception during: ['3658', 'destroy', '"Alvin', ' TX"', '"If Shantae doesn\'t get in Smash I will destroy my Wii U.']
#  exception during: ['3659', 'destroy', '', '"ng2x5 mhtw4fnet']
#  exception during: []
#  exception during: ['3750', 'destruction', 'All Around the World', '"How can we help save a beautiful town in Ontario from destruction by a power plant developer?']
#  exception during: ['3766', 'destruction', '', '"\'Every kingdom divided against itself is headed for destruction and no city or house divided against itself will stand.\'']
#  exception during: ['3771', 'destruction', 'Maldives', '"#ThingsIhate ']
#  exception during: ['3785', 'destruction', '', '"@AlexeiVolkov1 @McFaul']
#  exception during: ['3816', 'detonate', '"Ottawa', 'Ontario Canada"', '"Real Hip Hop: Apollo Brown Feat M.O.P. - Detonate ']
#  exception during: ['3833', 'detonate', 'back in japan ??????????', '"Detonate (feat. M?.?O?.?P?.?)']
#  exception during: ['3858', 'detonation', 'Bangalore. India', '"Do you want to play a game?']
#  exception during: ['http://t.co/sQFp6Ecz0i']
#  exception during: ['3893', 'detonation', 'Brisbane.', '"We are on our way to Hiroshima.']
#  exception during: ['3917', 'devastated', '', '"Good for her lol']
#  exception during: ['3919', 'devastated', '"Indonesia']
#  exception during: ['3951', 'devastation', '', '"In Kalmikya Astrakhan Volgagrad and Dagestan there is already no food left for the locusts']
#  exception during: []
#  exception during: ['3954', 'devastation', 'Seattle', '"http://t.co/IQoWZgvZNl #LatestNews #CNBC #CNN']
#  exception during: []
#  exception during: ['4038', 'disaster', 'los angeles', '"Keeps askin me what this means']
#  exception during: ['Not like i got the answers']
#  exception during: ['Plus if i say the wrong thing']
#  exception during: ['4096', 'displaced', '"Na:tinixw / Hoopa', ' Berkeley"', '"Elem Pomo helping the displaced from the Rocky Fire. Please consider!']
#  exception during: ['4112', 'drought', 'Caribbean', '"Heat wave is relentless:  91å¡F Feels Like 100 Humidity 55% +']
#  exception during: ['4206', 'drowned', '"United Kingdom', 'Fraserburgh"', '"@Stephen_Georg Hey Stephen Remember that time you drowned all the yellows']
#  exception during: []
#  exception during: ['4209', 'drowned', '', '"@ABCNews24 @PeterDutton_MP ']
#  exception during: ['4213', 'drowned', 'Pembroke NH', '"at the lake ']
#  exception during: ['*sees a dead fish*']
#  exception during: ['me: poor little guy i wonder what happened']
#  exception during: ['ashley: idk maybe it drowned']
#  exception during: ['4270', 'drowning', 'South Korea GMT+9', '"SometimesI can\'t even breathe well']
#  exception during: ["I feel like drowning and can't deal with my fear"]
#  exception during: ['4282', 'drowning', '"yorkshire']
#  exception during: ['', '#Islamic #state issue a new holiday #brochure lovely swimming pool for drowning in shooting range and the downside it costs a #bomb', '0\n4284', 'drowning', 'Coasts of Maine & California', 'Drowning sorrows in Jarmusch vampires.', '0\n4288', 'drowning', '', 'can still see it...blank expression...cheeks clapping in my face...marvins room playing subtlety in the back yet drowning out all the sound', '0\n4289', 'drowning', '', 'My mom is watching a show about bridges breaking/falling and the people on them drowning in their cars aka one of my biggest fears ????', '0\n4292', 'drowning', 'Pittsburgh ', 'Drowning in Actavis suicide', '0\n4293', 'drowning', '', 'What This Man Did To Save A Drowning Squirrel Is Absolutely Incredible']
#  exception during: ['4303', 'dust%20storm', 'qosqo', '"Totoooooo! Totoooooooooo!']
#  exception during: ['4327', 'dust%20storm', '\x89Û¢5\x89Û¢12\x89Û¢14\x89Û¢ | åÈ#SaviourSquadåÇ', '"I NEED THE DUST STORM FILM ASAP']
#  exception during: []
#  exception during: ['ALSO']
#  exception during: []
#  exception during: ['4366', 'earthquake', 'a box', '"@AGeekyFangirl14 \'s things she looks in a significant other:']
#  exception during: ['1. Beautiful eyes.']
#  exception during: ['2. Humor.']
#  exception during: ['3. Farts that creates an earthquake.']
#  exception during: []
#  exception during: ['4425', 'electrocute', '', '"She says that she\'d love to come help but']
#  exception during: ['The sea would....']
#  exception during: ['4441', 'electrocute', '"Houston', ' TX"', '"@FoxNews He still has his beard - has he been visited by any1 while in prison? If he keeps that hideous beard electrocute him! ']
#  exception during: ['4471', 'electrocuted', 'Oblivion?', '"Just thought I\'d let you all know...']
#  exception during: ['4487', 'electrocuted', '"Planet Eyal', ' Shandral System"', '"Zotar(50 skeleton alchemist) was electrocuted to death by Atamathon the Giant Golem on Golem Graveyard 1.']
#  exception during: ['4491', 'electrocuted', 'Atlanta', '"Worked in factory pressing designs onto T-shirts was electrocuted ']
#  exception during: ['4498', 'emergency', 'Michigan', '"A whistleblower lawsuit accuses that supervisor of sleeping on the job more than once according to officials. ']
#  exception during: []
#  exception during: ['4526', 'emergency', 'Adelaide', '"Myanmar floods: Childfund https://t.co/pQHQ4JnZTT']
#  exception during: ['4548', 'emergency%20plan', '"Antioch', ' CA "', '"4 Printable Emergency Plan Templates']
#  exception during: ['4553', 'emergency%20plan', '"Calgary', ' AB"', '"This from The City of Calgary - ']
#  exception during: []
#  exception during: ['City of Calgary has activated Municipal Emergency Plan']
#  exception during: []
#  exception during: ['4557', 'emergency%20plan', '"Nashville', ' TN"', '"Nieces these are especially good for you with the kids.']
#  exception during: []
#  exception during: ['4576', 'emergency%20plan', 'Im In Route ', '"\x89ÛÏ@based_georgie: yo forreal we need to have like an emergency action plan incase donald trump becomes president\x89Û\x9d']
#  exception during: ['4584', 'emergency%20plan', 'Indiana', '"Do you have a plan? Emergency Preparedness for #Families of']
#  exception during: ['4715', 'evacuate', 'New England', '"\'So again make sure to evacuate past the fire doors. Any questions? Yes?\'']
#  exception during: ["'Why would we open the doors to the fire!!?!??!?'"]
#  exception during: []
#  exception during: ['4773', 'evacuated', 'North West England UK', '"Trafford Centre film fans angry after Odeon cinema evacuated following false fire alarm: ']
#  exception during: ['4790', 'evacuated', 'Manchester', '"Trafford Centre film fans angry after Odeon cinema evacuated following false fire alarm: ']
#  exception during: ['4808', 'evacuated', '', '"I got evacuated from the cinema 30 mins through Inside Out']
#  exception during: ['4832', 'evacuation', '"Na:tinixw / Hoopa', ' Berkeley"', '"Elem Pomo helping the displaced from the Rocky Fire. Please consider!']
#  exception during: ['4856', 'evacuation', '', '"This is an evil generation']
#  exception during: ['Rock and roll evacuation!']
#  exception during: ['As far as the eye can see!']
#  exception during: ['4875', 'explode', '"Yamaku Academy', ' Class 3-4"', '"KS except every character is Shizune.']
#  exception during: ['4879', 'explode', 'The Windy City', '"Is he about to crash?']
#  exception during: ['Did the Queen die?']
#  exception during: ['Did something explode? ']
#  exception during: ['4888', 'explode', '"Yamaku Academy', ' Class 3-4"', '"Versions of KS where if a character was /every/ character world would explode.']
#  exception during: []
#  exception during: ['Rin']
#  exception during: ['Shizune']
#  exception during: ['Misha']
#  exception during: ['Emi']
#  exception during: ['Kenji']
#  exception during: ['Yuuko']
#  exception during: ['Nomiya']
#  exception during: ['4898', 'explode', 'they/them', '"tagged by @attackonstiles ']
#  exception during: []
#  exception during: ['millions']
#  exception during: ['a-punk']
#  exception during: ['hang em high']
#  exception during: ['alpha dog']
#  exception during: ['yeah boy and doll face']
#  exception during: ['little white lies']
#  exception during: ['4931', 'exploded', '', '"that exploded &amp; brought about the']
#  exception during: ["beginning of universe matches what's"]
#  exception during: ['mentioned in the versethe heaven and Earth']
#  exception during: ['4946', 'exploded', '', '"@MeryCormier haha! Exactly! Cosima is definitely in the hot seat. Lol']
#  exception during: ['4952', 'exploded', '', '"that exploded &amp; brought about the']
#  exception during: ["beginning of universe matches what's"]
#  exception during: ['mentioned in the versethe heaven and Earth']
#  exception during: ['4954', 'exploded', 'Germany', '"@lunasagalle @synapsenkotze ']
#  exception during: ['4978', 'explosion', '', '"A Time-Lapse Map of Every Nuclear Explosion Since 1945 - by Isao Hashimoto #War #atomicbomb ']
#  exception during: ['4989', 'explosion', '', '"#cum explosion!']
#  exception during: []
#  exception during: ['@begforcum ']
#  exception during: ['@allday_cumshots ']
#  exception during: ['@cumcovered ']
#  exception during: ['@sexycumshots ']
#  exception during: ['@Cumtown']
#  exception during: ['@BJ_Nutt']
#  exception during: ['@cumslut_2']
#  exception during: ['4997', 'explosion', 'Florida', '"#Tampa: Super Freestyle Explosion Live in Concert at Amalie Arena - Sep  19']
#  exception during: ['5004', 'explosion', 'Palestine Texas', '"You Are Invited to The Expo Explosion Summer Event 2015! ']
#  exception during: ['WHEN: August 14th Friday 2015']
#  exception during: ['5007', 'explosion', '', '"The insides of the explosion box..']
#  exception during: ['Get it customized the way you want!']
#  exception during: []
#  exception during: ['5018', 'eyewitness', 'Jammu and Kashmir', '"Eyewitness accounts of survivors of Hiroshima gleaned from a']
#  exception during: ['5041', 'eyewitness', 'Los Angeles... CA... USA', '"Aug. 06 2015 Radio Show articles \x89ÛÒ  ']
#  exception during: ['5069', 'famine', 'PanamÌÁ ', '"Top 3:']
#  exception during: ['* Turn on the Darkness']
#  exception during: ['* King Redeem - Queen Serene']
#  exception during: ['5083', 'famine', 'Massachusetts', '"Russia destroys food while people go hungry.  We\'re not the only ones with an insane government.']
#  exception during: ['5088', 'famine', '', '"A grade in Black Horse Famine[MEGA]. Score 0840728']
#  exception during: ['http://t.co/pdiit0AF3Q']
#  exception during: ['5102', 'famine', 'Ukraine', '"\'Food crematoria\' in Russia provoke outrage amid crisis famine memories']
#  exception during: ['5135', 'fatal', '"Sacramento', ' CA"', '"Stockton police are investigating a fatal drive-by shooting in north Stockton']
#  exception during: ['5146', 'fatal', '', '"Tell me why or why not']
#  exception during: ['to adopt in this way']
#  exception during: ['maybe I overlooked something']
#  exception during: ['fatal for me']
#  exception during: ['5169', 'fatalities', 'Cape Town', '"City implores motorists not to speed after more reports of animal fatalities near nature reserves']
#  exception during: ['5175', 'fatalities', '#WashingtonState #Seattle', '"#Seattle\'s deadliest red light runner intersections revealed']
#  exception during: ['5182', 'fatalities', '"Hope Road', ' Jamaica "', '"\'Use our roads wisely and prevent the carnage from continuing...let us have no fatalities over this holiday period..\'']
#  exception during: ['5186', 'fatalities', '', '"-??-']
#  exception during: ['; kitana']
#  exception during: ['? her fatalities slay me']
#  exception during: ['5188', 'fatalities', '', '"Mortal Kombat X: All Fatalities On Meat Predator.']
#  exception during: ['5264', 'fear', 'Yewa zone', '"The meaning I picked the one that changed my life: overcome fear behold wonder.']
#  exception during: []
#  exception during: ['5278', 'fear', '', '"The Opposite of Love is Fear Here\x89Ûªs Why']
#  exception during: ['5284', 'fear', '', '"I want to be with you forever']
#  exception during: ['Stay by my side']
#  exception during: ['On this special night']
#  exception during: []
#  exception during: ['5306', 'fear', '"Hilton Head', ' SC  "', '"@SenSanders Gd ideas. I\'m 77 wrked hard now have almost nothing fear lives with poor']
#  exception during: ['5310', 'fear', 'USA', '"Daily Reflections']
#  exception during: ['August 6']
#  exception during: ['DRIVEN']
#  exception during: ['5385', 'fire%20truck', 'Five down from the Coffeeshop', '"Came across this fire video not mine..enjoy..Babes way of saying hi to me while he\'s in the fire truck??']
#  exception during: ['5416', 'first%20responders', 'Long Eaton åá Derbyshire åá UK', '"Join #charity 10k #run event! @DoningtonDash']
#  exception during: ['11am start Sun 20 Sept 2015']
#  exception during: ['Castle Donington Community First Responders']
#  exception during: ['5468', 'flames', '"Manhattan', ' NY"', '"\'if you can\'t summon the flames directly from hell store bought is fine\'-me ']
#  exception during: ['5495', 'flames', 'Some where', '"So Pardon me while I burst into flames. ']
#  exception during: []
#  exception during: ['5514', 'flattened', 'Some other mansion', '"Flattened all cartoony-like.']
#  exception during: ['5529', 'flattened', 'Barbados', '"#Floored4 #Flattened ']
#  exception during: []
#  exception during: ['5552', 'flattened', '"Mississauga', ' Ontario"', '"@tweetingLew @tersestuff ']
#  exception during: []
#  exception during: ['Notley flattened Harper IN HIS Heartland']
#  exception during: ['5573', 'flood', '', '"It\'s been raining since you left me']
#  exception during: ["Now I'm drowning in the flood"]
#  exception during: ["You see I've always been a fighter"]
#  exception during: ['5602', 'flood', '', '"survived the plague']
#  exception during: ['floated the flood']
#  exception during: ['just peeked our heads above the mud']
#  exception during: ["no one's immune"]
#  exception during: ['deafening bells']
#  exception during: ['5631', 'flooding', 'I ACCEPT SONG REQUESTS', '"When the waves are flooding the shore']
#  exception during: ["And I can't find my way home anymore"]
#  exception during: ['5658', 'flooding', '', '"Flooding kills 166 displace over one million in Pakistan http://t.co/iCFQl7I9oP']
#  exception during: []
#  exception during: ['5662', 'floods', '', '"Who is bringing the tornadoes and floods. Who is bringing the climate change. God is after America He is plaguing her']
#  exception during: [' ']
#  exception during: ['5668', 'floods', 'Passamaquoddy', '"@ictyosaur I never thought it would be a wtf moment yet it\'s here after months of 90 degree heat']
#  exception during: ['5699', 'floods', '', '"Who is bringing the tornadoes and floods. Who is bringing the climate change. God is after America He is plaguing her']
#  exception during: [' ']
#  exception during: ['5707', 'floods', 'Rio de Janeiro', '"&gt;As soon as maintenance ends everyone floods the servers']
#  exception during: ['&gt;Servers destroyed by extreme load']
#  exception during: ['5710', 'floods', '', '"Who is bringing the tornadoes and floods. Who is bringing the climate change. God is after America He is plaguing her']
#  exception during: [' ']
#  exception during: ['5763', 'forest%20fires', '"Boise', ' Idaho"', '"8-5-2015 - 4:30 P.M. - Progress Being Made on Boise Forest Fires']
#  exception during: ['5781', 'forest%20fires', '', '"Campsite recommendations ']
#  exception during: ['Toilets /shower ']
#  exception during: ['Pub ']
#  exception during: ['Fires ']
#  exception during: ['No kids ']
#  exception during: ['Pizza shop ']
#  exception during: ['Forest ']
#  exception during: ['Pretty stream ']
#  exception during: ['No midges']
#  exception during: ['No snakes']
#  exception during: ['5789', 'hail', '"Carol Stream', ' Illinois"', '"GREAT MICHIGAN TECHNIQUE CAMP']
#  exception during: ['B1G THANKS TO @bmurph1019 ']
#  exception during: ['@hail_Youtsey . @termn8r13 ']
#  exception during: ['5868', 'hailstorm', 'facebook.com/tradcatknights', '"Canada: Hailstorm flash flooding slam Calgary knocks out power to 20k customers']
#  exception during: ['5874', 'hailstorm', '', '"This is why I am scared to leave my car under trees in a storm']
#  exception during: []
#  exception during: ['5887', 'harm', '', '"sticks and stones may break my bones']
#  exception during: ['5916', 'harm', '5/5 access / rt link please x', '"SO MANY SECURITY GARDS THIS IS GOOD. ']
#  exception during: ['5962', 'hazard', 'scandinavia', '"December 2011 court dismissed the group charge of rape victims saying \'getting raped was an occupational hazard..!\'']
#  exception during: []
#  exception during: ['5980', 'hazard', 'UK', '"Our tipster previews Chelsea v Swansea &amp; there\'s a 48/1 double! http://t.co/PFSrYJS1pc ']
#  exception during: ['6039', 'heat%20wave', '"Greenfield', ' Massachusetts"', '"Many thx for share and your comment Alex Lightman - ']
#  exception during: []
#  exception during: ['6047', 'heat%20wave', '"Karachi', ' Pakistan"', '"@WaseemBadami Condemning of Deaths More than 1000 due to Heat Wave in Karachi. ']
#  exception during: ['6053', 'heat%20wave', 'Pacific Northwest', '"UAE cool to Mideast heat-wave; rain watch latest [video]']
#  exception during: ['6086', 'hellfire', '', '"day 3 without my phone and due to my slow shite computers it is utter hellfire :\'(']
#  exception during: ['6137', 'hijack', 'Innerhalb der LÌ_cke', '"#GamerGate \'Our entire attempt to hijack your community destroy your industry and scam everyone in sight was just sarcastic\'.']
#  exception during: []
#  exception during: ['6167', 'hijack', '"Near Richmond', ' VA"', '"Another Mac vuln!']
#  exception during: []
#  exception during: ['6282', 'hijacking', '', '"Mom is hijacking my account to earn MCR STATUS!!!  Get your own account snort!  ']
#  exception during: ['6340', 'hostages', 'westwestwestwestwestwestwest', '"Russia stood down cold war nuke ban or face ocean superiority ']
#  exception during: ['Unconditional surrender next putin']
#  exception during: ['Game set match']
#  exception during: ['6346', 'hostages', '', '"Natalie Stavola our co-star explains her role in Love and Hostages. Check it out! #LH_movie #indiefilm #comingsoon']
#  exception during: ['6354', 'hostages', '', '"No #news of #hostages in #Libya']
#  exception during: []
#  exception during: ['http://t.co/eXil1bKzmP']
#  exception during: []
#  exception during: ['6370', 'hostages', '', '"New #Free #Porn #Clip! Taking Of Hostages Dangerous For Favors Free: http://t.co/MIubkZ77m6']
#  exception during: []
#  exception during: ['6372', 'hostages', '', '"No #news of #hostages in #Libya']
#  exception during: []
#  exception during: ['http://t.co/bjjOIfzUhL']
#  exception during: []
#  exception during: ['6375', 'hostages', '', '"No #news of #hostages in #Libya']
#  exception during: []
#  exception during: ['http://t.co/k9FBtcCU58']
#  exception during: []
#  exception during: ['6376', 'hostages', '', '"One Year on from the Sinjar Massacre #Yazidis Blast Lack of Action Over Hostages']
#  exception during: ['6384', 'hostages', '', '"@Nervana_1 ']
#  exception during: ['6404', 'hurricane', '"Books Published', ' USA"', '"Hurricane Dancers: The First Caribbean Pirate Shipwreck']
#  exception during: ['6422', 'hurricane', 'Chicopee MA', '"Entertain this thought for a moment:']
#  exception during: []
#  exception during: ['6436', 'injured', '"Srinagar', 'Kashmir"', '"Militants attack police post in Udhampur; 2 SPOs injured']
#  exception during: []
#  exception during: ['6455', 'injured', '"Lucknow', ' India"', '"http://t.co/qr3YPEkfOe ']
#  exception during: ['6485', 'injuries', '??', '"Injuries may be forgiven but not forgotten.']
#  exception during: []
#  exception during: ['6492', 'injuries', 'Emirates', '"Last time I checked Lots of injuries over the course of time = injury prone. ']
#  exception during: []
#  exception during: ['6494', 'injuries', 'Scottsdale. AZ', '"Next Man Up---AH SCREW THIS! I\'m so tired of injuries.  ']
#  exception during: []
#  exception during: ['6551', 'injury', 'Lahore', '"Live Cricket Score In All Match International']
#  exception during: ['Domestic']
#  exception during: ['Team Tour Team Squad']
#  exception during: ['Profile &amp; Injury']
#  exception during: ['Lamha Ba Lamha Update']
#  exception during: ['+']
#  exception during: ['FolloW']
#  exception during: ['6593', 'inundated', '"Boston', ' Massachusetts"', '"Body shops inundated with cars dented by hail... Good news insurance pays... Bad news :  you are stuck with deductible !']
#  exception during: ['6635', 'inundation', 'Asia European Continent Korea ', '"MEGALPOLIS Area Petting Party Shiver ']
#  exception during: ['Fear Instant .... GLOBAL Inundation OVERFLOW']
#  exception during: ['6638', 'inundation', '"Athens', ' Greece"', '"Potential Storm Surge Flooding Map by National Hurricane Center http://t.co/JZWRWlVlSj ']
#  exception during: ['6653', 'landslide', '', '".Sink Holes Earth Slides And Avalanches&gt;&gt;https://t.co/XrRLnheLaP']
#  exception during: ['6661', 'landslide', 'New York City', '"Inbounds/ Out of Bounds:']
#  exception during: []
#  exception during: ['6687', 'landslide', 'The Circle of Life', '"So when you\'re caught in a landslide']
#  exception during: ["I'll be there for you"]
#  exception during: ['And in the rain ']
#  exception during: ['give you sunshine']
#  exception during: ['6700', 'lava', '"Los Angeles', ' CA"', '"Seriously these two tracks (one new one old) are amazing. Fond memories with TEARS.']
#  exception during: ['https://t.co/sZ2RvwpWhj']
#  exception during: ['6724', 'lava', '"Newark', ' NJ"', '"https://t.co/4i0rKcbK1D']
#  exception during: ['6746', 'lava', '', '"I wish that the earth sea and sky up above']
#  exception during: ['6796', 'lightning', '"Waverly', ' IA"', '"\'When you walk away']
#  exception during: ['Nothing more to say']
#  exception during: ['See the lightning in your eyes']
#  exception during: ['6843', 'loud%20bang', 'English Midlands', '"St steel coffee cafetiere exploded this am with loud bang hot coffee &amp; grounds shot over table clean crockery phone']
#  exception during: ['6862', 'mass%20murder', '', '"@noah_anyname That\'s where the concentration camps and mass murder come in. ']
#  exception during: [' ']
#  exception during: ['6893', 'mass%20murder', '"Birmingham', ' England"', '"#DebateQuestionsWeWantToHear Why does #Saudi arabia and #Israel get away with mass murder?']
#  exception during: ['6921', 'mass%20murderer', '"Eww', ' I\'m not Paul Elam"', '"Reminder: Mass murderer and white supremacist Anders Breivik was also unsurprisingly an anti-feminist.']
#  exception during: ['6926', 'mass%20murderer', 'Hemel Hempstead', '"If your friends really were your friends they\'d support you regardless of your decisions.']
#  exception during: []
#  exception during: ['6946', 'massacre', '', '"@Cameron_WATE']
#  exception during: [' Parents of Colorado theater shooting victim fear copycat massacre']
#  exception during: []
#  exception during: ['http://t.co/LvlH3W3aWO']
#  exception during: ['#Antioch']
#  exception during: []
#  exception during: ['6950', 'massacre', '', '"@abc3340 ']
#  exception during: ['Parents of Colorado theater shooting victim fear copycat massacre']
#  exception during: []
#  exception during: ['http://t.co/LvlH3W3aWO']
#  exception during: ['#Antioch']
#  exception during: []
#  exception during: ['6956', 'massacre', '', '"Massacre at #Sinjar : Has the World Forgotten the #Yazidi ?']
#  exception during: ['http://t.co/WUh1g2BLP1']
#  exception during: ['6961', 'massacre', '', '"@KabarMesir @badr58 ']
#  exception during: ['Never dies a big Crime like RABAA MASSACRE as long the revolution is being observed.']
#  exception during: ['6970', 'massacre', '', '"Headed to the massacre ']
#  exception during: ['Bodies arriving everyday ']
#  exception during: ['What were those shells you heard ']
#  exception during: ['6971', 'massacre', '"Vancouver', ' BC', ' Canada"', '"@Bloodbath_TV favourite YouTube channel going right now.']
#  exception during: ['6985', 'massacre', '', '"@nataliealund ']
#  exception during: ['Parents of Colorado theater shooting victim fear copycat massacre']
#  exception during: []
#  exception during: ['http://t.co/LvlH3W3aWO']
#  exception during: ['#Antioch']
#  exception during: []
#  exception during: ['6988', 'massacre', '', '"@WKRN ']
#  exception during: ['Parents of Colorado theater shooting victim fear copycat massacre']
#  exception during: []
#  exception during: ['http://t.co/LvlH3W3aWO']
#  exception during: ['#Antioch']
#  exception during: []
#  exception during: ['7023', 'mayhem', '?? Made in the Philippines ??', '"_']
#  exception during: ['?????RETWEET']
#  exception during: ['???????']
#  exception during: ['?????FOLLOW ALL WHO RT']
#  exception during: ['???????']
#  exception during: ['?????FOLLOWBACK']
#  exception during: ['???????']
#  exception during: ['?????GAIN WITH ']
#  exception during: ['???????']
#  exception during: ['?????FOLLOW ?@ganseyman #RT_4_A_MENTION']
#  exception during: ['7065', 'meltdown', 'Proudly frozen Canuck eh !!', '"@JustinTrudeau ']
#  exception during: []
#  exception during: ['Most respected in world']
#  exception during: ['Best job recovery G7 and G20']
#  exception during: ['Best led during 2008 world meltdown']
#  exception during: []
#  exception during: ['7077', 'meltdown', "neil's kitchen  |  32215", '"def louis is tired plus the meltdown of fans when he confirmed he\'s a dad but some fans are reaching ']
#  exception during: ['7098', 'military', '', '"Russian #ushanka #winter #military fur hat (xl61-62) with soviet badge LINK:']
#  exception during: ['7109', 'military', '', '"Hat #russian soviet army kgb  military #cossack #ushanka  LINK:']
#  exception during: ['7115', 'military', 'Hearts & Minds', '"Thank You Senator @timkaine for your Leadership on #IranDeal ']
#  exception during: ['Our Military deserves nothing less. THANK YOU!!']
#  exception during: []
#  exception during: ['7168', 'mudslide', 'London', '"#GBBO The difference between Paul and Mary my dears']
#  exception during: ["Paul: 'it looks like a mudslide'"]
#  exception during: ['7174', 'mudslide', 'The Pumpkin Carriage of Dreams', '"@Lolly_Knickers It\'s a mudslide. ']
#  exception during: ["It's like chewing on a rubber tyre."]
#  exception during: ["And with those I'm DONE."]
#  exception during: ['7196', 'natural%20disaster', '"Orlando/Cocoa Beach', ' FL"', '"\'Up to 40% of businesses affected by a natural or man-made disaster never reopen\'']
#  exception during: ['7223', 'natural%20disaster', 'America of Founding Fathers', '"This is the natural and unavoidable consequence of socialism everywhere it has been tried.']
#  exception during: ['7230', 'natural%20disaster', 'America of Founding Fathers', '"This is the natural and unavoidable consequence of socialism everywhere it has been tried.']
#  exception during: ['7241', 'natural%20disaster', 'America of Founding Fathers', '"This is the natural and unavoidable consequence of socialism everywhere it has been tried.']
#  exception during: ['7250', 'nuclear%20disaster', '', '"Nuclear deal disaster.']
#  exception during: []
#  exception during: ['7252', 'nuclear%20disaster', 'The Netherlands', '"?#FUKUSHIMA?#TEPCO?']
#  exception during: ['Fukushima Nuclear Disaster | Increased Thyroid Cancer in #US - Integrative Cancer Answers']
#  exception during: ['7255', 'nuclear%20disaster', 'Marbella. Spain', '"http://t.co/GaM7otGISw']
#  exception during: ['7278', 'nuclear%20disaster', 'San Francisco Bay Area', '"3 Former Executives to Be Prosecuted in Fukushima Nuclear #Disaster.']
#  exception during: []
# ...
#  exception during: []
#  exception during: ['8624', 'seismic', '"Bokaro Steel City', ' Jharkhand"', '"@kakajambori ??']
#  exception during: ['U control the future of india..']
#  exception during: ['8633', 'seismic', '"Mogadishu', ' Somalia"', '"Exploration Takes Seismic Shift in #Gabon to #Somalia']
#  exception during: ['8642', 'sinkhole', 'Unknown ', '"Sinkhole Selfies: You Wont Believe What\'s In The Brooklyn Sinkhole!: ']
#  exception during: ['8656', 'sinkhole', 'Newcastle', '"150-Foot Sinkhole Opens in Lowndes County Residential Area']
#  exception during: ['8677', 'sinkhole', 'Hinterestland', '"Sinkhole Selfies: You Wont Believe What\'s In The Brooklyn Sinkhole!: ']
#  exception during: ['8686', 'sinkhole', 'Newcastle', '"Sinkhole leaking sewage opens in housing estate']
#  exception during: ['8710', 'sinking', 'Canada', '"@AP ']
#  exception during: ['8726', 'sinking', 'HOMRA.', '"In your eyes I see the hope']
#  exception during: ['I once knew.']
#  exception during: ["I'm sinking."]
#  exception during: ["I'm sinking"]
#  exception during: ['away from you.']
#  exception during: ["Don't turn around"]
#  exception during: ["you'll see..."]
#  exception during: []
#  exception during: ['8776', 'siren', '', '"Pharma overloaded with a loud cry like an emergency siren. ']
#  exception during: []
#  exception during: ['8781', 'siren', '"California', ' USA"', '"Can you save']
#  exception during: ['Can you save my']
#  exception during: ['8795', 'sirens', '... -.- -.--', '"Thu Aug 06 2015 01:20:32 GMT+0000 (UTC)']
#  exception during: ['#millcityio #20150613']
#  exception during: ['8832', 'sirens', 'az', '"connor franta: damn sirens I hope everyone is okay. ']
#  exception during: []
#  exception during: ['8900', 'snowstorm', '"Huntington', ' WV"', '"sorry-I built a fire by my desk already. RT@irishirr']
#  exception during: ['8913', 'snowstorm', '', '"@dirk_trossen ']
#  exception during: []
#  exception during: ['8916', 'snowstorm', 'This Is Paradise. Relax. ', '"\x89ÛÏ@LordBrathwaite: Everyone Here: Ahh I hate snow!']
#  exception during: []
#  exception during: ['Me: Lol u call this a snowstorm..?']
#  exception during: []
#  exception during: ['8949', 'storm', '"Chicago', ' IL"', '"How to prepare your #property for a #storm:']
#  exception during: []
#  exception during: ['8962', 'storm', 'philly', '"It\'s okay I welcome the rain. ']
#  exception during: ['8979', 'storm', 'EspaÌ±a - Spain - Espagne', '"NASAHurricane? EASTERN PACIFIC *Full Update* Satellite Sees Formation of Eastern Pacific\'s Tropical Storm Hilda']
#  exception during: ['8992', 'stretcher', 'CamaquÌ£/Pelotas', '"Somebody get the doctor I\'m feelin\' pretty poor. Somebody get the stretcher']
#  exception during: ['9009', 'stretcher', '', '"How to Freeze Fruits and Veggies']
#  exception during: ['9085', 'structural%20failure', 'Reality', '"\'Jet fuel cant melt steel\'']
#  exception during: ["'The structural failure is illogical'"]
#  exception during: ["'The second plane crashing into the building is fake'"]
#  exception during: ['9159', 'suicide%20bomber', 'Worldwide', '"17 killed in S\x89ÛªArabia mosque suicide bombing']
#  exception during: []
#  exception during: ['9172', 'suicide%20bomber', '', '"@Abu_Baraa1 Suicide bomber targets Saudi mosque at least 13 dead - Suicide bomber targets Saudi mosque at least 13 dead']
#  exception during: ['9197', 'suicide%20bombing', 'England', '"Suicide bombing for Da\'esh is (rightly) despicable. Suicide bombing for Ocalan/ Marxism?']
#  exception during: []
#  exception during: ['9233', 'suicide%20bombing', 'Lagos', '"Imagine a school where suicide bombing Is being taught the teachers would say to the students...']
#  exception during: []
#  exception during: ['9252', 'sunk', 'Bon Temps Louisiana', '"So if I capsize on your thighs high tide B-5 you sunk my battleship']
#  exception during: ['9311', 'survive', '"???????', ' Texas"', '"DON\'T MAKE FUN OF THEM FOR TRYING']
#  exception during: ['9317', 'survive', 'Kansas', '"Escaping her captors was the 1st step. Now she must survive a deadly storm &amp; a wild-looking recluse.']
#  exception during: ['BETRAYED']
#  exception during: ['http://t.co/0Q040STkCV']
#  exception during: ['9343', 'survived', '', '"Update: I survived. No canoe. ']
#  exception during: []
#  exception during: ['9368', 'survived', '"Predjama', ' Eslovenia."', '"[+]']
#  exception during: []
#  exception during: ['Such a lonely day']
#  exception during: ["And it's mine"]
#  exception during: ["It's a day that I'm glad I survived ..."]
#  exception during: []
#  exception during: ['9378', 'survived', 'Glasgow', '"Today your life could change forever - #Chronicillness can\'t be avoided - It can be survived']
#  exception during: []
#  exception during: ['9397', 'survivors', '', '"Tricycle toddler atomic bomb']
#  exception during: ['9404', 'survivors', '"Chicago', ' IL"', '"RT @kotowsa: South Sudan\x89Ûªs war on women: survivors say rape has become \'just a normal thing\' ']
#  exception during: ['9410', 'survivors', '', '"#WorldNews']
#  exception during: [' Fears over missing migrants in Med - BBC News - Home:']
#  exception during: ['9445', 'terrorism', '', '"Truth...']
#  exception during: ['https://t.co/h6amECX5K7']
#  exception during: ['#News']
#  exception during: ['#BBC']
#  exception during: ['#CNN']
#  exception during: ['#Islam']
#  exception during: ['#Truth']
#  exception during: ['#god']
#  exception during: ['#ISIS']
#  exception during: ['#terrorism']
#  exception during: ['#Quran']
#  exception during: ['9449', 'terrorism', '', '"Truth...']
#  exception during: ['https://t.co/nXS3Z1kxiD']
#  exception during: ['#News']
#  exception during: ['#BBC']
#  exception during: ['#CNN']
#  exception during: ['#Islam']
#  exception during: ['#Truth']
#  exception during: ['#god']
#  exception during: ['#ISIS']
#  exception during: ['#terrorism']
#  exception during: ['#Quran']
#  exception during: ['9454', 'terrorism', '', '"Truth...']
#  exception during: ['https://t.co/beJfTYgJIL']
#  exception during: ['#News']
#  exception during: ['#BBC']
#  exception during: ['#CNN']
#  exception during: ['#Islam']
#  exception during: ['#Truth']
#  exception during: ['#god']
#  exception during: ['#ISIS']
#  exception during: ['#terrorism']
#  exception during: ['#Quran']
#  exception during: ['9463', 'terrorism', '', '"Does this apply to Muslims/terrorism?']
#  exception during: ['9480', 'terrorism', '', '"Truth...']
#  exception during: ['https://t.co/2Y4RGob7pj']
#  exception during: ['#News']
#  exception during: ['#BBC']
#  exception during: ['#CNN']
#  exception during: ['#Islam']
#  exception during: ['#Truth']
#  exception during: ['#god']
#  exception during: ['#ISIS']
#  exception during: ['#terrorism']
#  exception during: ['#Quran']
#  exception during: ['9482', 'terrorism', '', '"Truth...']
#  exception during: ['https://t.co/p5ZIcjUdXO']
#  exception during: ['#News']
#  exception during: ['#BBC']
#  exception during: ['#CNN']
#  exception during: ['#Islam']
#  exception during: ['#Truth']
#  exception during: ['#god']
#  exception during: ['#ISIS']
#  exception during: ['#terrorism']
#  exception during: ['#Quran']
#  exception during: ['9486', 'terrorism', '', '"Truth...']
#  exception during: ['https://t.co/k44tL3rfMy']
#  exception during: ['#News']
#  exception during: ['#BBC']
#  exception during: ['#CNN']
#  exception during: ['#Islam']
#  exception during: ['#Truth']
#  exception during: ['#god']
#  exception during: ['#ISIS']
#  exception during: ['#terrorism']
#  exception during: ['#Quran']
#  exception during: ['9490', 'terrorism', '', '"Truth...']
#  exception during: ['https://t.co/4ZQrsAQrRT']
#  exception during: ['#News']
#  exception during: ['#BBC']
#  exception during: ['#CNN']
#  exception during: ['#Islam']
#  exception during: ['#Truth']
#  exception during: ['#god']
#  exception during: ['#ISIS']
#  exception during: ['#terrorism']
#  exception during: ['#Quran']
#  exception during: ['9525', 'terrorist', 'MAD as Hell', '"RT AbbsWinston: #Zionist #Terrorist Demolish Tire Repair Shop Structure in #Bethlehem']
#  exception during: ['9552', 'threat', '"London', ' UK"', '"Generational \x89Û÷British schism\x89Ûª over privacy threat of drones http://t.co/dqtMTPqmBR']
#  exception during: ['9595', 'thunder', '??', '"Oh shit its rly sheeting']
#  exception during: ["Aaaaaand there's the thunder and lightning"]
#  exception during: ['9597', 'thunder', '"Accra', 'Ghana"', '"Please please u gotta listen to @leonalewis # essenceOfMe and thunder it\'s major']
#  exception during: ['9632', 'thunderstorm', 'WORDLDWIDE', '"Conditions for Paris FR at 4:00 am CEST: Current Conditions:']
#  exception during: ['Fair 68 FForecast:']
#  exception during: ['Thu - Sunny. High: 87 Low: 61']
#  exception during: ['9652', 'thunderstorm', 'Helsinki', '"Thunderstorm in Helsinki']
#  exception during: ['9686', 'tornado', '"Dindigul', 'TamilNadu."', '"@kunalkapoor Photo of the Day: Storm']
#  exception during: ['Chaser']
#  exception during: ['http://t.co/4WJy7seHmw']
#  exception during: ['9722', 'tragedy', '"Harper Woods', ' MI"', '"A real life tragedy:']
#  exception during: ['9729', 'tragedy', 'dubai ', '"@TOIIndiaNews ofcourse ']
#  exception during: []
#  exception during: ['Just 8 minute b4 tragedy another train had crossed this place ']
#  exception during: []
#  exception during: ['9749', 'tragedy', 'MÌ©xico', '"I\'m gunning down romance']
#  exception during: ['It never did a thing for me']
#  exception during: ['But heartache and misery']
#  exception during: ['9759', 'trapped', '"PA', ' USA"', '"Leitchfield KY:']
#  exception during: []
#  exception during: [' Bella Edward &amp; Rosalie need rescue/adoption/local foster home(s)/sponsorships.']
#  exception during: []
#  exception during: ['9772', 'trapped', 'New York City', '"Billionaires have a plan to free half a billion dollars trapped in Venezuela for two years @BlakeSchmidt reports.']
#  exception during: []
#  exception during: ['9833', 'trauma', 'The Jewfnited State', '"Why #Marijuana Is Critical For Research in Treating #PTSD']
#  exception during: []
#  exception during: ['http://t.co/T6fuAhFp7p ']
#  exception during: ['9850', 'trauma', 'Minneapolis/St. Paul', '"Simmering beneath #NHL good times the league\'s own concussion issues @PioneerPress']
#  exception during: []
#  exception during: ['9888', 'traumatised', 'Londonstan', '"\x89ÛÏ@_keits: @LIVA_GOTTA get a gold chain you\'ll understand\x89Û\x9d']
#  exception during: []
#  exception during: ['9972', 'tsunami', '', '"Crptotech tsunami and banks.']
#  exception during: ['9985', 'tsunami', 'The Netherlands', '"?#FUKUSHIMA?#TEPCO?']
#  exception during: ['Mountains of debris from the Japanese tsunami have floated to the West Coast']
#  exception during: ['10012', 'twister', '"Las Vegas', ' NV "', '"950. If a landslide tumbles down todayI\'m on your side']
#  exception during: []
#  exception during: ['And if a twister sweeps it all away-']
#  exception during: []
#  exception during: ['10028', 'twister', '', '"Check out \'Want Twister Tickets AND A VIP EXPERIENCE To See SHANIA? CLICK HERE:\' at  http://t.co/3GEROQ49o1']
#  exception during: ['10038', 'twister', '', '"\'How many men would a human hew if a human could hew men?\'']
#  exception during: []
#  exception during: ['10100', 'typhoon', '', '"4Yygb mhtw4fnet']
#  exception during: []
#  exception during: ['10117', 'upheaval', '"eBooks', ' North America"', '"Medieval Upheaval (Hardy Boys: The Secret Files Book 18)']
#  exception during: ['10125', 'upheaval', 'IG/SC:bjfordiani', '"But...! Oh! ']
#  exception during: []
#  exception during: ['How rich the soil?!']
#  exception during: []
#  exception during: ['How wonderful the upheaval!?']
#  exception during: []
#  exception during: ['10127', 'upheaval', '', '"How long O Lord (Study 3)']
#  exception during: ['10153', 'upheaval', 'Karachi', '"@nytimes ']
#  exception during: ['10168', 'violent%20storm', 'Toronto', '"Thunder pounds north goes black']
#  exception during: ["a deep bruise on the sky's chest"]
#  exception during: ['wind cries its pain.  ']
#  exception during: ['A summer storm has a tough life']
#  exception during: ['10173', 'violent%20storm', 'Worldwide', '"Violent Forces Radio: Now Playing Agony - Storm of the apocalypse']
#  exception during: ['10179', 'violent%20storm', 'Worldwide', '"Violent Forces Radio: Now Playing Acid Storm - Scourgue Of The Gods']
#  exception during: ['10182', 'violent%20storm', 'us', '"U.S.PACIFIC COMMAND.']
#  exception during: ['I can see it!']
#  exception during: ['They gave their all in the peace unity festival']
#  exception during: ['It disappears when freedom']
#  exception during: ['10207', 'violent%20storm', '3rd Eye Chakra', '"Violent video: Ukraine rioters brutally beat police storm local admin building']
#  exception during: ['10209', 'volcano', ' ? ??????? ? ( ?? å¡ ? ? ? å¡)', '"nside a Dragon\'s belly. Or an ice cave under']
#  exception during: ['a volcano in Kamchatka | Photography by']
#  exception during: ['å©Daniel Korzhonov']
#  exception during: ['10210', 'volcano', 'USA', '"Japan Aogashima Volcano. By Unknown - Check It Out! http://t.co/OegFQBIqIq']
#  exception during: ['10303', 'weapon', '"kediri', '', 'jawa timur"', '"@muttatek m believe my \'blue\' not isis kwwwkwwwk ']
#  exception during: ["Without weapon 'blue' will hug me jiahahahha "]
#  exception during: ['10320', 'weapon', 'www.twitch.tv/PKSparkxx', '"Slosher is GOAT. Freaking love that weapon. Can\'t wait to do an episode of Splatdown with it.']
#  exception during: []
#  exception during: ['10332', 'weapon', 'Denver Colorado. Fun Times', '"Lol']
#  exception during: ['Look how tough some people talk that live in some of the most gang infested cities in America']
#  exception during: ["Your mouth isn't a weapon"]
#  exception during: ['10338', 'weapons', '"Odawara', ' Japan"', '"The thing with rules is break it once it becomes easier the next time.']
#  exception during: ['10361', 'weapons', 'Multinational *****', '"@JamesMelville Some old testimony of weapons used to promote conflicts']
#  exception during: ['Tactics - corruption &amp; infiltration of groups']
#  exception during: ['10378', 'weapons', 'Kernow', '"Slightly doesn\'t help that he has Suh and Wake in practice. But think he will get there. A lot of weapons! #FinsUp ']
#  exception during: ['10382', 'weapons', 'California', '"Navy: No charges against officer for weapons violations in Chattanooga attack']
#  exception during: ['10387', 'whirlwind', 'Somewhere between here & there', '"I stand alone']
#  exception during: ["don't piss and moan"]
#  exception during: ['about my choices made']
#  exception during: ['If I must reap the whirlwind so be it']
#  exception during: ['10396', 'whirlwind', '', '"life can wild when... ']
#  exception during: ['10411', 'whirlwind', '140920-21 & 150718-19 BEIJING', '"{INFO} Baekhyun and Suho will be attending the Idol Sports Championship on August 10th']
#  exception during: ['Cr: SYJEXO ']
#  exception during: ['10478', 'wild%20fires', 'Indiana', '"\'Your love will surely come find us']
#  exception during: ['10486', 'wildfire', '', '"kc5kH mhtw4fnet']
#  exception during: []
#  exception during: ['10598', 'wounded', 'FILM OUT LATE 2015', '"Prince Phillip said of the numbers of those murdered by the British at Amritsar...']
#  exception during: []
#  exception during: ['10605', 'wounded', '', '"Have you ever seen the President ']
#  exception during: ['who killed your wounded child?']
#  exception during: ["Or the man that crashed your sister's plane "]
#  exception during: ['10651', 'wounds', '', '"white ppl bruise easily.. where ur bullet wounds at ?? ']
#  exception during: []
#  exception during: ['10680', 'wounds', '"cody', ' austin follows ?*?"', '"Crawling in my skin']
#  exception during: ['10691', 'wreck', ' ?currently writing a book?', '"I\'m a friggin wreck destiel sucks (read the vine description)']
#  exception during: ['10755', 'wreckage', '', '"Related News: ']
#  exception during: []
#  exception during: ['Plane Wreckage Found Is Part Of Missing MH370 Malaysia Prime Minister?Says']
#  exception during: ['10768', 'wreckage', '', '"Wreckage is MH370: Najib']
#  exception during: ['10795', 'wrecked', '"Santa Cruz', ' CA"', '"Israel wrecked my home. Now it wants my land. ']
#  exception during: ['10808', 'wrecked', '', '"300K exotic car wrecked in train accident ']

# %%
train_x, val_x, train_y, val_y = split_dataset(images=reviews,
                                                labels=labels,
                                                train_split=0.85,
                                                shuffle=True)

# %%
numwords = 20000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=numwords, oov_token='<OOV>')
pad = tf.keras.preprocessing.sequence.pad_sequences

tokenizer.fit_on_texts(train_x)

train_seq = tokenizer.texts_to_sequences(train_x)
test_seq = tokenizer.texts_to_sequences(val_x)

# %%
mx_len = 0
for i in train_seq:
    mx_len = max(mx_len, len(i))
print(mx_len)
# Out:
# 32

# %%
train_seq_pad = pad(train_seq, padding='post', truncating='post', maxlen=mx_len)
test_seq_pad = pad(test_seq, padding='post', truncating='post', maxlen=mx_len)

# %%
print(f'train_seq_pad: {train_seq_pad.shape}')
print(f'test_seq_pad: {test_seq_pad.shape}')
# Out:
# train_seq_pad: (6463, 32)
# test_seq_pad: (1141, 32)

# %%
class EarlyStoppingMonitor(tf.keras.callbacks.Callback):
    def __init__(self):
        super(EarlyStoppingMonitor, self).__init__()
        self.current_best = 0
        self.monitor = 'val_acc'

    def on_epoch_end(self, epoch, logs=None):
        # get parameter like below
        # current_train_precision = logs.get('precision')
        # self.model.stop_training = True

        if self.current_best < logs.get(self.monitor):
            self.current_best = logs.get(self.monitor)
            self.model.save(f'best_model_as_{self.monitor}_{self.current_best:.3f}.h5')
        # print('\n\n******* Stopping on Defined Threshold *******')

    def on_train_end(self, logs=None):
        if self.model.stop_training:
            print("\n\n\n****** Early Stopping *******")

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=numwords+1, output_dim=10, input_length=mx_len),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

loss = tf.keras.losses.BinaryCrossentropy()
optim = tf.keras.optimizers.Adam(3*1e-5)

model.compile(
    loss = loss,
    optimizer=optim,
    metrics=['acc']
)

# LR = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch / 20), verbose=1)

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model.compile(
    loss = loss,
    optimizer=optim,
    metrics=['acc']
)

# %%
history = model.fit(
    train_seq_pad,
    train_y,
    epochs=30,
    batch_size=16,
    validation_data=(test_seq_pad, val_y),
    callbacks= [tensorboard_callback]
)
# Out:
# Epoch 1/30
# 404/404 [==============================] - 6s 10ms/step - loss: 0.6912 - acc: 0.5699 - val_loss: 0.6898 - val_acc: 0.5697
# Epoch 2/30
# 404/404 [==============================] - 3s 8ms/step - loss: 0.6887 - acc: 0.5700 - val_loss: 0.6874 - val_acc: 0.5697
# Epoch 3/30
# 404/404 [==============================] - 4s 9ms/step - loss: 0.6862 - acc: 0.5700 - val_loss: 0.6850 - val_acc: 0.5697
# Epoch 4/30
# 404/404 [==============================] - 4s 9ms/step - loss: 0.6836 - acc: 0.5700 - val_loss: 0.6827 - val_acc: 0.5697
# Epoch 5/30
# 404/404 [==============================] - 4s 9ms/step - loss: 0.6810 - acc: 0.5700 - val_loss: 0.6804 - val_acc: 0.5697
# Epoch 6/30
# 404/404 [==============================] - 4s 9ms/step - loss: 0.6781 - acc: 0.5700 - val_loss: 0.6778 - val_acc: 0.5697
# Epoch 7/30
# 404/404 [==============================] - 4s 9ms/step - loss: 0.6743 - acc: 0.5700 - val_loss: 0.6741 - val_acc: 0.5697
# Epoch 8/30
# 404/404 [==============================] - 4s 9ms/step - loss: 0.6686 - acc: 0.5700 - val_loss: 0.6687 - val_acc: 0.5697
# Epoch 9/30
# 404/404 [==============================] - 3s 8ms/step - loss: 0.6599 - acc: 0.5700 - val_loss: 0.6606 - val_acc: 0.5697
# Epoch 10/30
# 404/404 [==============================] - 3s 9ms/step - loss: 0.6474 - acc: 0.5714 - val_loss: 0.6500 - val_acc: 0.5714
# Epoch 11/30
# 404/404 [==============================] - 3s 8ms/step - loss: 0.6321 - acc: 0.5938 - val_loss: 0.6386 - val_acc: 0.6117
# Epoch 12/30
# 404/404 [==============================] - 3s 8ms/step - loss: 0.6156 - acc: 0.6440 - val_loss: 0.6267 - val_acc: 0.6468
# Epoch 13/30
# 404/404 [==============================] - 3s 8ms/step - loss: 0.5988 - acc: 0.6949 - val_loss: 0.6143 - val_acc: 0.6792
# Epoch 14/30
# 404/404 [==============================] - 3s 8ms/step - loss: 0.5818 - acc: 0.7343 - val_loss: 0.6030 - val_acc: 0.6933
# Epoch 15/30
# 404/404 [==============================] - 3s 8ms/step - loss: 0.5642 - acc: 0.7636 - val_loss: 0.5932 - val_acc: 0.7082
# Epoch 16/30
# 404/404 [==============================] - 3s 8ms/step - loss: 0.5460 - acc: 0.7818 - val_loss: 0.5816 - val_acc: 0.7178
# Epoch 17/30
# 404/404 [==============================] - 3s 8ms/step - loss: 0.5272 - acc: 0.8002 - val_loss: 0.5711 - val_acc: 0.7362
# Epoch 18/30
# 404/404 [==============================] - 3s 7ms/step - loss: 0.5076 - acc: 0.8140 - val_loss: 0.5600 - val_acc: 0.7450
# Epoch 19/30
# 404/404 [==============================] - 3s 7ms/step - loss: 0.4869 - acc: 0.8259 - val_loss: 0.5508 - val_acc: 0.7520
# Epoch 20/30
# 404/404 [==============================] - 3s 8ms/step - loss: 0.4647 - acc: 0.8375 - val_loss: 0.5424 - val_acc: 0.7555
# Epoch 21/30
# 404/404 [==============================] - 4s 9ms/step - loss: 0.4411 - acc: 0.8482 - val_loss: 0.5343 - val_acc: 0.7616
# Epoch 22/30
# 404/404 [==============================] - 4s 9ms/step - loss: 0.4163 - acc: 0.8615 - val_loss: 0.5185 - val_acc: 0.7677
# Epoch 23/30
# 404/404 [==============================] - 4s 9ms/step - loss: 0.3921 - acc: 0.8720 - val_loss: 0.5177 - val_acc: 0.7695
# Epoch 24/30
# 404/404 [==============================] - 3s 8ms/step - loss: 0.3683 - acc: 0.8810 - val_loss: 0.5099 - val_acc: 0.7713
# Epoch 25/30
# 404/404 [==============================] - 3s 8ms/step - loss: 0.3463 - acc: 0.8895 - val_loss: 0.5158 - val_acc: 0.7695
# Epoch 26/30
# 404/404 [==============================] - 4s 9ms/step - loss: 0.3264 - acc: 0.8949 - val_loss: 0.5228 - val_acc: 0.7695
# Epoch 27/30
# 404/404 [==============================] - 4s 9ms/step - loss: 0.3067 - acc: 0.9016 - val_loss: 0.5065 - val_acc: 0.7791
# Epoch 28/30
# 404/404 [==============================] - 4s 9ms/step - loss: 0.2878 - acc: 0.9076 - val_loss: 0.5216 - val_acc: 0.7695
# Epoch 29/30
# 404/404 [==============================] - 4s 9ms/step - loss: 0.2709 - acc: 0.9129 - val_loss: 0.5133 - val_acc: 0.7765
# Epoch 30/30
# 404/404 [==============================] - 3s 9ms/step - loss: 0.2552 - acc: 0.9180 - val_loss: 0.5088 - val_acc: 0.7791

# %%
import matplotlib.pyplot as plt
m2 = tf.keras.models.load_model('./best_model_as_val_acc_0.772.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 import matplotlib.pyplot as plt
# ----> 2 m2 = tf.keras.models.load_model('./best_model_as_val_acc_0.772.h5')
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File /usr/local/lib/python3.8/dist-packages/keras/saving/save.py:206, in load_model(filepath, custom_objects, compile, options)
#     204 if isinstance(filepath_str, str):
#     205   if not tf.io.gfile.exists(filepath_str):
# --> 206     raise IOError(f'No file or directory found at {filepath_str}')
#     208   if tf.io.gfile.isdir(filepath_str):
#     209     return saved_model_load.load(filepath_str, compile, options)
#
# OSError: No file or directory found at ./best_model_as_val_acc_0.772.h5

# %%
y = m2.predict(
    test_seq_pad
)
# Out:
# 36/36 [==============================] - 1s 4ms/step

# %%
p = y > 0.5

# %%
q = p.astype(int)

# %%
from sklearn.metrics import  accuracy_score
accuracy_score(q, val_y)
# Out:
# 0.7721297107800176
