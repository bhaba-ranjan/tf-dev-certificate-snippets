# %%
import numpy as np
import tensorflow as tf
import os
import random
from shutil import copyfile

# %%
tf.__version__
# Out:
# '2.13.0-rc0'

# %% [markdown]
# ### Seprate Images

# %%
def create_folders(folder_names, root_path):
    for folder in folder_names:
        os.makedirs(os.path.join(root_path, folder))

# %% [markdown]
# ### Sorting and checking for corrupted files (if training Directory contains a Mix of Binary classes)

# %%
def is_corrupted(file_path):
    if os.path.getsize(file_path) == 0:
        print(f'{file_path} is corrupted')
        return True
    else:
        return False
    
def get_split_index(file_list, split_size):
    return int(len(file_list) * split_size)


def check_and_sort(files, root_path, cat_dir, dog_dir):
    
    copied_files = 0

    for file in files:
        
        # Your checking logic here to seprate files according to the criteria
        initials = file.split('.')[0]
        file_path = os.path.join(root_path, file)

        # copying files into two different dirs to use ImageGenerator
        if initials == 'cat' and is_corrupted(file_path) == False:            
            copyfile(file_path, os.path.join(cat_dir, file))
            copied_files += 1
        
        if initials == 'dog' and is_corrupted(file_path) == False:
            copyfile(file_path, os.path.join(dog_dir, file))
            copied_files += 1
    
    print(f'Total Files: {len(files)} \nTotal Copied Files: {copied_files}')

# %%
def get_pre_trained_model(input_shape = None):
    
    # block_11_add for MobilenetV2
    # mixed7 for inceptionV3
    
    pre_trained_model = tf.keras.applications.inception_v3.InceptionV3(
        input_shape= input_shape,
        include_top= False,
        weights='imagenet',        
    )
    

    # pre_trained_model = tf.keras.applications.mobilenet_v2.MobileNetV2(
    #     input_shape= input_shape,
    #     include_top= False,
    #     weights='imagenet',        
    # )

    # pre_trained_model = tf.keras.applications.resnet50.ResNet50(
    #     input_shape= input_shape,
    #     include_top= False,
    #     weights='imagenet',        
    # )

    # pre_trained_model = tf.keras.applications.efficientnet.EfficientNetB0(
    #     input_shape= input_shape,
    #     include_top= False,
    #     weights='imagenet',        
    # )


    # set layers trainable to false
    for layer in pre_trained_model.layers:
        layer.trainable = False

    # print(pre_trained_model.summary())

    return pre_trained_model

# %%
def get_layer_output( pre_trained_model, layer_name):
    selected_layer = pre_trained_model.get_layer(layer_name)
    output = selected_layer.output
    return output

# %%
# This is the path of the dataset
root_path_src = '../datasets/dogs-vs-cats/train/'

# This two paths need to exist inside of which the folders will be created

root_path_train = '../datasets/dogs-vs-cats-seprated/train/'
root_path_validation = '../datasets/dogs-vs-cats-seprated/validation/'
folder_names = ['cats', 'dogs']


# create folders: **the root_path should exist in the system
create_folders(folder_names= folder_names, root_path=root_path_train)
create_folders(folder_names= folder_names, root_path=root_path_validation)

# Get a list of file names in the direcotry
files = os.listdir(root_path_src)

# Random sample files if needed
files = random.sample(files, len(files))

# Find the index to split the file
# Convert it into training and Validation Split
index = get_split_index(files, .50)


# Copy file from src to destination directory
# It also checks if the files are corrupted
check_and_sort( files[:index] ,root_path_src, os.path.join(root_path_train, 'cats'), os.path.join(root_path_train, 'dogs'))
check_and_sort( files[index:] ,root_path_src, os.path.join(root_path_validation, 'cats'), os.path.join(root_path_validation, 'dogs'))
# Out:
# Total Files: 12500
# Total Copied Files: 12500
# Total Files: 12500
# Total Copied Files: 12500

# %%
# Image data generator with inbuilt augmentations
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1.0/255,
                                                                  rotation_range=40,
                                                                  horizontal_flip= True,
                                                                  vertical_flip=False,
                                                                  zoom_range=0.0,
                                                                  width_shift_range=0.0,
                                                                  height_shift_range=0.0,                                                                  
                                                                  fill_mode='nearest')

# Test / Validation generator should not have augmentation
test_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1.0/255)

# %%
# To create classes from already segregated path
train_images = train_generator.flow_from_directory(root_path_train,
                                                   target_size= (224,224),
                                                   batch_size=12, 
                                                   shuffle=True,
                                                   class_mode='binary')

test_images = test_generator.flow_from_directory(root_path_validation,
                                                   target_size= (224,224),
                                                   batch_size=12,
                                                   class_mode='binary')
# Out:
# Found 12500 images belonging to 2 classes.
# Found 12500 images belonging to 2 classes.

# %%
pre_trained_model = get_pre_trained_model(input_shape=(224,224,3))

print(pre_trained_model.summary())
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_54 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  conv2d_470 (Conv2D)         (None, 111, 111, 32)         864       ['input_54[0][0]']
#
#  batch_normalization_470 (B  (None, 111, 111, 32)         96        ['conv2d_470[0][0]']
#  atchNormalization)
#
#  activation_470 (Activation  (None, 111, 111, 32)         0         ['batch_normalization_470[0][0
#  )                                                                  ]']
#
#  conv2d_471 (Conv2D)         (None, 109, 109, 32)         9216      ['activation_470[0][0]']
#
#  batch_normalization_471 (B  (None, 109, 109, 32)         96        ['conv2d_471[0][0]']
#  atchNormalization)
#
#  activation_471 (Activation  (None, 109, 109, 32)         0         ['batch_normalization_471[0][0
#  )                                                                  ]']
#
#  conv2d_472 (Conv2D)         (None, 109, 109, 64)         18432     ['activation_471[0][0]']
#
#  batch_normalization_472 (B  (None, 109, 109, 64)         192       ['conv2d_472[0][0]']
#  atchNormalization)
#
#  activation_472 (Activation  (None, 109, 109, 64)         0         ['batch_normalization_472[0][0
#  )                                                                  ]']
#
#  max_pooling2d_20 (MaxPooli  (None, 54, 54, 64)           0         ['activation_472[0][0]']
#  ng2D)
#
#  conv2d_473 (Conv2D)         (None, 54, 54, 80)           5120      ['max_pooling2d_20[0][0]']
#
#  batch_normalization_473 (B  (None, 54, 54, 80)           240       ['conv2d_473[0][0]']
#  atchNormalization)
#
#  activation_473 (Activation  (None, 54, 54, 80)           0         ['batch_normalization_473[0][0
#  )                                                                  ]']
#
#  conv2d_474 (Conv2D)         (None, 52, 52, 192)          138240    ['activation_473[0][0]']
#
#  batch_normalization_474 (B  (None, 52, 52, 192)          576       ['conv2d_474[0][0]']
#  atchNormalization)
#
#  activation_474 (Activation  (None, 52, 52, 192)          0         ['batch_normalization_474[0][0
#  )                                                                  ]']
#
#  max_pooling2d_21 (MaxPooli  (None, 25, 25, 192)          0         ['activation_474[0][0]']
#  ng2D)
#
#  conv2d_478 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_21[0][0]']
#
#  batch_normalization_478 (B  (None, 25, 25, 64)           192       ['conv2d_478[0][0]']
#  atchNormalization)
#
#  activation_478 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_478[0][0
#  )                                                                  ]']
#
#  conv2d_476 (Conv2D)         (None, 25, 25, 48)           9216      ['max_pooling2d_21[0][0]']
#
#  conv2d_479 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_478[0][0]']
#
#  batch_normalization_476 (B  (None, 25, 25, 48)           144       ['conv2d_476[0][0]']
#  atchNormalization)
#
#  batch_normalization_479 (B  (None, 25, 25, 96)           288       ['conv2d_479[0][0]']
#  atchNormalization)
#
#  activation_476 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_476[0][0
#  )                                                                  ]']
#
#  activation_479 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_479[0][0
#  )                                                                  ]']
#
#  average_pooling2d_45 (Aver  (None, 25, 25, 192)          0         ['max_pooling2d_21[0][0]']
#  agePooling2D)
#
#  conv2d_475 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_21[0][0]']
#
#  conv2d_477 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_476[0][0]']
#
#  conv2d_480 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_479[0][0]']
#
#  conv2d_481 (Conv2D)         (None, 25, 25, 32)           6144      ['average_pooling2d_45[0][0]']
#
#  batch_normalization_475 (B  (None, 25, 25, 64)           192       ['conv2d_475[0][0]']
#  atchNormalization)
#
#  batch_normalization_477 (B  (None, 25, 25, 64)           192       ['conv2d_477[0][0]']
#  atchNormalization)
#
#  batch_normalization_480 (B  (None, 25, 25, 96)           288       ['conv2d_480[0][0]']
#  atchNormalization)
#
#  batch_normalization_481 (B  (None, 25, 25, 32)           96        ['conv2d_481[0][0]']
#  atchNormalization)
#
#  activation_475 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_475[0][0
#  )                                                                  ]']
#
#  activation_477 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_477[0][0
#  )                                                                  ]']
#
#  activation_480 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_480[0][0
#  )                                                                  ]']
#
#  activation_481 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_481[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 25, 25, 256)          0         ['activation_475[0][0]',
#                                                                      'activation_477[0][0]',
#                                                                      'activation_480[0][0]',
#                                                                      'activation_481[0][0]']
#
#  conv2d_485 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_485 (B  (None, 25, 25, 64)           192       ['conv2d_485[0][0]']
#  atchNormalization)
#
#  activation_485 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_485[0][0
#  )                                                                  ]']
#
#  conv2d_483 (Conv2D)         (None, 25, 25, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_486 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_485[0][0]']
#
#  batch_normalization_483 (B  (None, 25, 25, 48)           144       ['conv2d_483[0][0]']
#  atchNormalization)
#
#  batch_normalization_486 (B  (None, 25, 25, 96)           288       ['conv2d_486[0][0]']
#  atchNormalization)
#
#  activation_483 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_483[0][0
#  )                                                                  ]']
#
#  activation_486 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_486[0][0
#  )                                                                  ]']
#
#  average_pooling2d_46 (Aver  (None, 25, 25, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_482 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_484 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_483[0][0]']
#
#  conv2d_487 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_486[0][0]']
#
#  conv2d_488 (Conv2D)         (None, 25, 25, 64)           16384     ['average_pooling2d_46[0][0]']
#
#  batch_normalization_482 (B  (None, 25, 25, 64)           192       ['conv2d_482[0][0]']
#  atchNormalization)
#
#  batch_normalization_484 (B  (None, 25, 25, 64)           192       ['conv2d_484[0][0]']
#  atchNormalization)
#
#  batch_normalization_487 (B  (None, 25, 25, 96)           288       ['conv2d_487[0][0]']
#  atchNormalization)
#
#  batch_normalization_488 (B  (None, 25, 25, 64)           192       ['conv2d_488[0][0]']
#  atchNormalization)
#
#  activation_482 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_482[0][0
#  )                                                                  ]']
#
#  activation_484 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_484[0][0
#  )                                                                  ]']
#
#  activation_487 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_487[0][0
#  )                                                                  ]']
#
#  activation_488 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_488[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 25, 25, 288)          0         ['activation_482[0][0]',
#                                                                      'activation_484[0][0]',
#                                                                      'activation_487[0][0]',
#                                                                      'activation_488[0][0]']
#
#  conv2d_492 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_492 (B  (None, 25, 25, 64)           192       ['conv2d_492[0][0]']
#  atchNormalization)
#
#  activation_492 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_492[0][0
#  )                                                                  ]']
#
#  conv2d_490 (Conv2D)         (None, 25, 25, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_493 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_492[0][0]']
#
#  batch_normalization_490 (B  (None, 25, 25, 48)           144       ['conv2d_490[0][0]']
#  atchNormalization)
#
#  batch_normalization_493 (B  (None, 25, 25, 96)           288       ['conv2d_493[0][0]']
#  atchNormalization)
#
#  activation_490 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_490[0][0
#  )                                                                  ]']
#
#  activation_493 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_493[0][0
#  )                                                                  ]']
#
#  average_pooling2d_47 (Aver  (None, 25, 25, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_489 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_491 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_490[0][0]']
#
#  conv2d_494 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_493[0][0]']
#
#  conv2d_495 (Conv2D)         (None, 25, 25, 64)           18432     ['average_pooling2d_47[0][0]']
#
#  batch_normalization_489 (B  (None, 25, 25, 64)           192       ['conv2d_489[0][0]']
#  atchNormalization)
#
#  batch_normalization_491 (B  (None, 25, 25, 64)           192       ['conv2d_491[0][0]']
#  atchNormalization)
#
#  batch_normalization_494 (B  (None, 25, 25, 96)           288       ['conv2d_494[0][0]']
#  atchNormalization)
#
#  batch_normalization_495 (B  (None, 25, 25, 64)           192       ['conv2d_495[0][0]']
#  atchNormalization)
#
#  activation_489 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_489[0][0
#  )                                                                  ]']
#
#  activation_491 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_491[0][0
#  )                                                                  ]']
#
#  activation_494 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_494[0][0
#  )                                                                  ]']
#
#  activation_495 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_495[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 25, 25, 288)          0         ['activation_489[0][0]',
#                                                                      'activation_491[0][0]',
#                                                                      'activation_494[0][0]',
#                                                                      'activation_495[0][0]']
#
#  conv2d_497 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_497 (B  (None, 25, 25, 64)           192       ['conv2d_497[0][0]']
#  atchNormalization)
#
#  activation_497 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_497[0][0
#  )                                                                  ]']
#
#  conv2d_498 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_497[0][0]']
#
#  batch_normalization_498 (B  (None, 25, 25, 96)           288       ['conv2d_498[0][0]']
#  atchNormalization)
#
#  activation_498 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_498[0][0
#  )                                                                  ]']
#
#  conv2d_496 (Conv2D)         (None, 12, 12, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_499 (Conv2D)         (None, 12, 12, 96)           82944     ['activation_498[0][0]']
#
#  batch_normalization_496 (B  (None, 12, 12, 384)          1152      ['conv2d_496[0][0]']
#  atchNormalization)
#
#  batch_normalization_499 (B  (None, 12, 12, 96)           288       ['conv2d_499[0][0]']
#  atchNormalization)
#
#  activation_496 (Activation  (None, 12, 12, 384)          0         ['batch_normalization_496[0][0
#  )                                                                  ]']
#
#  activation_499 (Activation  (None, 12, 12, 96)           0         ['batch_normalization_499[0][0
#  )                                                                  ]']
#
#  max_pooling2d_22 (MaxPooli  (None, 12, 12, 288)          0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 12, 12, 768)          0         ['activation_496[0][0]',
#                                                                      'activation_499[0][0]',
#                                                                      'max_pooling2d_22[0][0]']
#
#  conv2d_504 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_504 (B  (None, 12, 12, 128)          384       ['conv2d_504[0][0]']
#  atchNormalization)
#
#  activation_504 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_504[0][0
#  )                                                                  ]']
#
#  conv2d_505 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_504[0][0]']
#
#  batch_normalization_505 (B  (None, 12, 12, 128)          384       ['conv2d_505[0][0]']
#  atchNormalization)
#
#  activation_505 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_505[0][0
#  )                                                                  ]']
#
#  conv2d_501 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_506 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_505[0][0]']
#
#  batch_normalization_501 (B  (None, 12, 12, 128)          384       ['conv2d_501[0][0]']
#  atchNormalization)
#
#  batch_normalization_506 (B  (None, 12, 12, 128)          384       ['conv2d_506[0][0]']
#  atchNormalization)
#
#  activation_501 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_501[0][0
#  )                                                                  ]']
#
#  activation_506 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_506[0][0
#  )                                                                  ]']
#
#  conv2d_502 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_501[0][0]']
#
#  conv2d_507 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_506[0][0]']
#
#  batch_normalization_502 (B  (None, 12, 12, 128)          384       ['conv2d_502[0][0]']
#  atchNormalization)
#
#  batch_normalization_507 (B  (None, 12, 12, 128)          384       ['conv2d_507[0][0]']
#  atchNormalization)
#
#  activation_502 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_502[0][0
#  )                                                                  ]']
#
#  activation_507 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_507[0][0
#  )                                                                  ]']
#
#  average_pooling2d_48 (Aver  (None, 12, 12, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_500 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_503 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_502[0][0]']
#
#  conv2d_508 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_507[0][0]']
#
#  conv2d_509 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_48[0][0]']
#
#  batch_normalization_500 (B  (None, 12, 12, 192)          576       ['conv2d_500[0][0]']
#  atchNormalization)
#
#  batch_normalization_503 (B  (None, 12, 12, 192)          576       ['conv2d_503[0][0]']
#  atchNormalization)
#
#  batch_normalization_508 (B  (None, 12, 12, 192)          576       ['conv2d_508[0][0]']
#  atchNormalization)
#
#  batch_normalization_509 (B  (None, 12, 12, 192)          576       ['conv2d_509[0][0]']
#  atchNormalization)
#
#  activation_500 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_500[0][0
#  )                                                                  ]']
#
#  activation_503 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_503[0][0
#  )                                                                  ]']
#
#  activation_508 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_508[0][0
#  )                                                                  ]']
#
#  activation_509 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_509[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 12, 12, 768)          0         ['activation_500[0][0]',
#                                                                      'activation_503[0][0]',
#                                                                      'activation_508[0][0]',
#                                                                      'activation_509[0][0]']
#
#  conv2d_514 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_514 (B  (None, 12, 12, 160)          480       ['conv2d_514[0][0]']
#  atchNormalization)
#
#  activation_514 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_514[0][0
#  )                                                                  ]']
#
#  conv2d_515 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_514[0][0]']
#
#  batch_normalization_515 (B  (None, 12, 12, 160)          480       ['conv2d_515[0][0]']
#  atchNormalization)
#
#  activation_515 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_515[0][0
#  )                                                                  ]']
#
#  conv2d_511 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_516 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_515[0][0]']
#
#  batch_normalization_511 (B  (None, 12, 12, 160)          480       ['conv2d_511[0][0]']
#  atchNormalization)
#
#  batch_normalization_516 (B  (None, 12, 12, 160)          480       ['conv2d_516[0][0]']
#  atchNormalization)
#
#  activation_511 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_511[0][0
#  )                                                                  ]']
#
#  activation_516 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_516[0][0
#  )                                                                  ]']
#
#  conv2d_512 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_511[0][0]']
#
#  conv2d_517 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_516[0][0]']
#
#  batch_normalization_512 (B  (None, 12, 12, 160)          480       ['conv2d_512[0][0]']
#  atchNormalization)
#
#  batch_normalization_517 (B  (None, 12, 12, 160)          480       ['conv2d_517[0][0]']
#  atchNormalization)
#
#  activation_512 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_512[0][0
#  )                                                                  ]']
#
#  activation_517 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_517[0][0
#  )                                                                  ]']
#
#  average_pooling2d_49 (Aver  (None, 12, 12, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_510 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_513 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_512[0][0]']
#
#  conv2d_518 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_517[0][0]']
#
#  conv2d_519 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_49[0][0]']
#
#  batch_normalization_510 (B  (None, 12, 12, 192)          576       ['conv2d_510[0][0]']
#  atchNormalization)
#
#  batch_normalization_513 (B  (None, 12, 12, 192)          576       ['conv2d_513[0][0]']
#  atchNormalization)
#
#  batch_normalization_518 (B  (None, 12, 12, 192)          576       ['conv2d_518[0][0]']
#  atchNormalization)
#
#  batch_normalization_519 (B  (None, 12, 12, 192)          576       ['conv2d_519[0][0]']
#  atchNormalization)
#
#  activation_510 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_510[0][0
#  )                                                                  ]']
#
#  activation_513 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_513[0][0
#  )                                                                  ]']
#
#  activation_518 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_518[0][0
#  )                                                                  ]']
#
#  activation_519 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_519[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 12, 12, 768)          0         ['activation_510[0][0]',
#                                                                      'activation_513[0][0]',
#                                                                      'activation_518[0][0]',
#                                                                      'activation_519[0][0]']
#
#  conv2d_524 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_524 (B  (None, 12, 12, 160)          480       ['conv2d_524[0][0]']
#  atchNormalization)
#
#  activation_524 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_524[0][0
#  )                                                                  ]']
#
#  conv2d_525 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_524[0][0]']
#
#  batch_normalization_525 (B  (None, 12, 12, 160)          480       ['conv2d_525[0][0]']
#  atchNormalization)
#
#  activation_525 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_525[0][0
#  )                                                                  ]']
#
#  conv2d_521 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_526 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_525[0][0]']
#
#  batch_normalization_521 (B  (None, 12, 12, 160)          480       ['conv2d_521[0][0]']
#  atchNormalization)
#
#  batch_normalization_526 (B  (None, 12, 12, 160)          480       ['conv2d_526[0][0]']
#  atchNormalization)
#
# ...
#
#  batch_normalization_551 (B  (None, 5, 5, 384)            1152      ['conv2d_551[0][0]']
#  atchNormalization)
#
#  activation_547 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_547[0][0
#  )                                                                  ]']
#
#  activation_551 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_551[0][0
#  )                                                                  ]']
#
#  conv2d_548 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_547[0][0]']
#
#  conv2d_549 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_547[0][0]']
#
#  conv2d_552 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_551[0][0]']
#
#  conv2d_553 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_551[0][0]']
#
#  average_pooling2d_52 (Aver  (None, 5, 5, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_546 (Conv2D)         (None, 5, 5, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_548 (B  (None, 5, 5, 384)            1152      ['conv2d_548[0][0]']
#  atchNormalization)
#
#  batch_normalization_549 (B  (None, 5, 5, 384)            1152      ['conv2d_549[0][0]']
#  atchNormalization)
#
#  batch_normalization_552 (B  (None, 5, 5, 384)            1152      ['conv2d_552[0][0]']
#  atchNormalization)
#
#  batch_normalization_553 (B  (None, 5, 5, 384)            1152      ['conv2d_553[0][0]']
#  atchNormalization)
#
#  conv2d_554 (Conv2D)         (None, 5, 5, 192)            245760    ['average_pooling2d_52[0][0]']
#
#  batch_normalization_546 (B  (None, 5, 5, 320)            960       ['conv2d_546[0][0]']
#  atchNormalization)
#
#  activation_548 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_548[0][0
#  )                                                                  ]']
#
#  activation_549 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_549[0][0
#  )                                                                  ]']
#
#  activation_552 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_552[0][0
#  )                                                                  ]']
#
#  activation_553 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_553[0][0
#  )                                                                  ]']
#
#  batch_normalization_554 (B  (None, 5, 5, 192)            576       ['conv2d_554[0][0]']
#  atchNormalization)
#
#  activation_546 (Activation  (None, 5, 5, 320)            0         ['batch_normalization_546[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 5, 5, 768)            0         ['activation_548[0][0]',
#                                                                      'activation_549[0][0]']
#
#  concatenate_10 (Concatenat  (None, 5, 5, 768)            0         ['activation_552[0][0]',
#  e)                                                                  'activation_553[0][0]']
#
#  activation_554 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_554[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 5, 5, 2048)           0         ['activation_546[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_10[0][0]',
#                                                                      'activation_554[0][0]']
#
#  conv2d_559 (Conv2D)         (None, 5, 5, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_559 (B  (None, 5, 5, 448)            1344      ['conv2d_559[0][0]']
#  atchNormalization)
#
#  activation_559 (Activation  (None, 5, 5, 448)            0         ['batch_normalization_559[0][0
#  )                                                                  ]']
#
#  conv2d_556 (Conv2D)         (None, 5, 5, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_560 (Conv2D)         (None, 5, 5, 384)            1548288   ['activation_559[0][0]']
#
#  batch_normalization_556 (B  (None, 5, 5, 384)            1152      ['conv2d_556[0][0]']
#  atchNormalization)
#
#  batch_normalization_560 (B  (None, 5, 5, 384)            1152      ['conv2d_560[0][0]']
#  atchNormalization)
#
#  activation_556 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_556[0][0
#  )                                                                  ]']
#
#  activation_560 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_560[0][0
#  )                                                                  ]']
#
#  conv2d_557 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_556[0][0]']
#
#  conv2d_558 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_556[0][0]']
#
#  conv2d_561 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_560[0][0]']
#
#  conv2d_562 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_560[0][0]']
#
#  average_pooling2d_53 (Aver  (None, 5, 5, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_555 (Conv2D)         (None, 5, 5, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_557 (B  (None, 5, 5, 384)            1152      ['conv2d_557[0][0]']
#  atchNormalization)
#
#  batch_normalization_558 (B  (None, 5, 5, 384)            1152      ['conv2d_558[0][0]']
#  atchNormalization)
#
#  batch_normalization_561 (B  (None, 5, 5, 384)            1152      ['conv2d_561[0][0]']
#  atchNormalization)
#
#  batch_normalization_562 (B  (None, 5, 5, 384)            1152      ['conv2d_562[0][0]']
#  atchNormalization)
#
#  conv2d_563 (Conv2D)         (None, 5, 5, 192)            393216    ['average_pooling2d_53[0][0]']
#
#  batch_normalization_555 (B  (None, 5, 5, 320)            960       ['conv2d_555[0][0]']
#  atchNormalization)
#
#  activation_557 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_557[0][0
#  )                                                                  ]']
#
#  activation_558 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_558[0][0
#  )                                                                  ]']
#
#  activation_561 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_561[0][0
#  )                                                                  ]']
#
#  activation_562 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_562[0][0
#  )                                                                  ]']
#
#  batch_normalization_563 (B  (None, 5, 5, 192)            576       ['conv2d_563[0][0]']
#  atchNormalization)
#
#  activation_555 (Activation  (None, 5, 5, 320)            0         ['batch_normalization_555[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 5, 5, 768)            0         ['activation_557[0][0]',
#                                                                      'activation_558[0][0]']
#
#  concatenate_11 (Concatenat  (None, 5, 5, 768)            0         ['activation_561[0][0]',
#  e)                                                                  'activation_562[0][0]']
#
#  activation_563 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_563[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 5, 5, 2048)           0         ['activation_555[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_11[0][0]',
#                                                                      'activation_563[0][0]']
#
# ==================================================================================================
# Total params: 21802784 (83.17 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# #### Model Check Point

# %%
check_point_cb = tf.keras.callbacks.ModelCheckpoint(
    filepath= 'best_model_as_per_val_accuracy.h5',# path to save the model if the check point matches
    save_best_only= True,    
    monitor= 'val_accuracy', # check if the it is logged as val_acc or val_accuracy
    mode= 'auto' # options {min, max, auto}
)

# %%
# block_11_add for MobilenetV2
# mixed7 for inceptionV3


output_layer = get_layer_output(pre_trained_model, layer_name='mixed7')

x = tf.keras.layers.Flatten()(output_layer)
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(inputs = pre_trained_model.input, outputs=x)

loss = tf.keras.losses.BinaryCrossentropy()
optimiser = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001)

model.compile(loss=loss, optimizer= optimiser, 
              metrics=[
                  'accuracy', 
                #   tf.keras.metrics.Precision(), 
                #   tf.keras.metrics.Recall() 
                  ])

# %%
history = model.fit(train_images, 
                    epochs= 1, 
                    validation_data=test_images,
                    callbacks=[check_point_cb])
# Out:
# 2023-06-21 17:56:06.285874: I tensorflow/core/common_runtime/executor.cc:1210] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-21 17:56:07.308852: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1042/1042 [==============================] - ETA: 0s - loss: 0.1007 - accuracy: 0.9612
# 2023-06-21 17:57:53.279084: I tensorflow/core/common_runtime/executor.cc:1210] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-21 17:57:53.535431: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/bhabaranjanpanigrahi/.local/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1042/1042 [==============================] - 196s 185ms/step - loss: 0.1007 - accuracy: 0.9612 - val_loss: 0.0579 - val_accuracy: 0.9786

# %%
loaded_model = tf.keras.models.load_model('./best_model_as_per_val_accuracy.h5')

# %%
loaded_model.summary()
# Out:
# Model: "model_79"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_54 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  conv2d_470 (Conv2D)         (None, 111, 111, 32)         864       ['input_54[0][0]']
#
#  batch_normalization_470 (B  (None, 111, 111, 32)         96        ['conv2d_470[0][0]']
#  atchNormalization)
#
#  activation_470 (Activation  (None, 111, 111, 32)         0         ['batch_normalization_470[0][0
#  )                                                                  ]']
#
#  conv2d_471 (Conv2D)         (None, 109, 109, 32)         9216      ['activation_470[0][0]']
#
#  batch_normalization_471 (B  (None, 109, 109, 32)         96        ['conv2d_471[0][0]']
#  atchNormalization)
#
#  activation_471 (Activation  (None, 109, 109, 32)         0         ['batch_normalization_471[0][0
#  )                                                                  ]']
#
#  conv2d_472 (Conv2D)         (None, 109, 109, 64)         18432     ['activation_471[0][0]']
#
#  batch_normalization_472 (B  (None, 109, 109, 64)         192       ['conv2d_472[0][0]']
#  atchNormalization)
#
#  activation_472 (Activation  (None, 109, 109, 64)         0         ['batch_normalization_472[0][0
#  )                                                                  ]']
#
#  max_pooling2d_20 (MaxPooli  (None, 54, 54, 64)           0         ['activation_472[0][0]']
#  ng2D)
#
#  conv2d_473 (Conv2D)         (None, 54, 54, 80)           5120      ['max_pooling2d_20[0][0]']
#
#  batch_normalization_473 (B  (None, 54, 54, 80)           240       ['conv2d_473[0][0]']
#  atchNormalization)
#
#  activation_473 (Activation  (None, 54, 54, 80)           0         ['batch_normalization_473[0][0
#  )                                                                  ]']
#
#  conv2d_474 (Conv2D)         (None, 52, 52, 192)          138240    ['activation_473[0][0]']
#
#  batch_normalization_474 (B  (None, 52, 52, 192)          576       ['conv2d_474[0][0]']
#  atchNormalization)
#
#  activation_474 (Activation  (None, 52, 52, 192)          0         ['batch_normalization_474[0][0
#  )                                                                  ]']
#
#  max_pooling2d_21 (MaxPooli  (None, 25, 25, 192)          0         ['activation_474[0][0]']
#  ng2D)
#
#  conv2d_478 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_21[0][0]']
#
#  batch_normalization_478 (B  (None, 25, 25, 64)           192       ['conv2d_478[0][0]']
#  atchNormalization)
#
#  activation_478 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_478[0][0
#  )                                                                  ]']
#
#  conv2d_476 (Conv2D)         (None, 25, 25, 48)           9216      ['max_pooling2d_21[0][0]']
#
#  conv2d_479 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_478[0][0]']
#
#  batch_normalization_476 (B  (None, 25, 25, 48)           144       ['conv2d_476[0][0]']
#  atchNormalization)
#
#  batch_normalization_479 (B  (None, 25, 25, 96)           288       ['conv2d_479[0][0]']
#  atchNormalization)
#
#  activation_476 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_476[0][0
#  )                                                                  ]']
#
#  activation_479 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_479[0][0
#  )                                                                  ]']
#
#  average_pooling2d_45 (Aver  (None, 25, 25, 192)          0         ['max_pooling2d_21[0][0]']
#  agePooling2D)
#
#  conv2d_475 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_21[0][0]']
#
#  conv2d_477 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_476[0][0]']
#
#  conv2d_480 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_479[0][0]']
#
#  conv2d_481 (Conv2D)         (None, 25, 25, 32)           6144      ['average_pooling2d_45[0][0]']
#
#  batch_normalization_475 (B  (None, 25, 25, 64)           192       ['conv2d_475[0][0]']
#  atchNormalization)
#
#  batch_normalization_477 (B  (None, 25, 25, 64)           192       ['conv2d_477[0][0]']
#  atchNormalization)
#
#  batch_normalization_480 (B  (None, 25, 25, 96)           288       ['conv2d_480[0][0]']
#  atchNormalization)
#
#  batch_normalization_481 (B  (None, 25, 25, 32)           96        ['conv2d_481[0][0]']
#  atchNormalization)
#
#  activation_475 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_475[0][0
#  )                                                                  ]']
#
#  activation_477 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_477[0][0
#  )                                                                  ]']
#
#  activation_480 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_480[0][0
#  )                                                                  ]']
#
#  activation_481 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_481[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 25, 25, 256)          0         ['activation_475[0][0]',
#                                                                      'activation_477[0][0]',
#                                                                      'activation_480[0][0]',
#                                                                      'activation_481[0][0]']
#
#  conv2d_485 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_485 (B  (None, 25, 25, 64)           192       ['conv2d_485[0][0]']
#  atchNormalization)
#
#  activation_485 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_485[0][0
#  )                                                                  ]']
#
#  conv2d_483 (Conv2D)         (None, 25, 25, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_486 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_485[0][0]']
#
#  batch_normalization_483 (B  (None, 25, 25, 48)           144       ['conv2d_483[0][0]']
#  atchNormalization)
#
#  batch_normalization_486 (B  (None, 25, 25, 96)           288       ['conv2d_486[0][0]']
#  atchNormalization)
#
#  activation_483 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_483[0][0
#  )                                                                  ]']
#
#  activation_486 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_486[0][0
#  )                                                                  ]']
#
#  average_pooling2d_46 (Aver  (None, 25, 25, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_482 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_484 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_483[0][0]']
#
#  conv2d_487 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_486[0][0]']
#
#  conv2d_488 (Conv2D)         (None, 25, 25, 64)           16384     ['average_pooling2d_46[0][0]']
#
#  batch_normalization_482 (B  (None, 25, 25, 64)           192       ['conv2d_482[0][0]']
#  atchNormalization)
#
#  batch_normalization_484 (B  (None, 25, 25, 64)           192       ['conv2d_484[0][0]']
#  atchNormalization)
#
#  batch_normalization_487 (B  (None, 25, 25, 96)           288       ['conv2d_487[0][0]']
#  atchNormalization)
#
#  batch_normalization_488 (B  (None, 25, 25, 64)           192       ['conv2d_488[0][0]']
#  atchNormalization)
#
#  activation_482 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_482[0][0
#  )                                                                  ]']
#
#  activation_484 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_484[0][0
#  )                                                                  ]']
#
#  activation_487 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_487[0][0
#  )                                                                  ]']
#
#  activation_488 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_488[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 25, 25, 288)          0         ['activation_482[0][0]',
#                                                                      'activation_484[0][0]',
#                                                                      'activation_487[0][0]',
#                                                                      'activation_488[0][0]']
#
#  conv2d_492 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_492 (B  (None, 25, 25, 64)           192       ['conv2d_492[0][0]']
#  atchNormalization)
#
#  activation_492 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_492[0][0
#  )                                                                  ]']
#
#  conv2d_490 (Conv2D)         (None, 25, 25, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_493 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_492[0][0]']
#
#  batch_normalization_490 (B  (None, 25, 25, 48)           144       ['conv2d_490[0][0]']
#  atchNormalization)
#
#  batch_normalization_493 (B  (None, 25, 25, 96)           288       ['conv2d_493[0][0]']
#  atchNormalization)
#
#  activation_490 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_490[0][0
#  )                                                                  ]']
#
#  activation_493 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_493[0][0
#  )                                                                  ]']
#
#  average_pooling2d_47 (Aver  (None, 25, 25, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_489 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_491 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_490[0][0]']
#
#  conv2d_494 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_493[0][0]']
#
#  conv2d_495 (Conv2D)         (None, 25, 25, 64)           18432     ['average_pooling2d_47[0][0]']
#
#  batch_normalization_489 (B  (None, 25, 25, 64)           192       ['conv2d_489[0][0]']
#  atchNormalization)
#
#  batch_normalization_491 (B  (None, 25, 25, 64)           192       ['conv2d_491[0][0]']
#  atchNormalization)
#
#  batch_normalization_494 (B  (None, 25, 25, 96)           288       ['conv2d_494[0][0]']
#  atchNormalization)
#
#  batch_normalization_495 (B  (None, 25, 25, 64)           192       ['conv2d_495[0][0]']
#  atchNormalization)
#
#  activation_489 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_489[0][0
#  )                                                                  ]']
#
#  activation_491 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_491[0][0
#  )                                                                  ]']
#
#  activation_494 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_494[0][0
#  )                                                                  ]']
#
#  activation_495 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_495[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 25, 25, 288)          0         ['activation_489[0][0]',
#                                                                      'activation_491[0][0]',
#                                                                      'activation_494[0][0]',
#                                                                      'activation_495[0][0]']
#
#  conv2d_497 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_497 (B  (None, 25, 25, 64)           192       ['conv2d_497[0][0]']
#  atchNormalization)
#
#  activation_497 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_497[0][0
#  )                                                                  ]']
#
#  conv2d_498 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_497[0][0]']
#
#  batch_normalization_498 (B  (None, 25, 25, 96)           288       ['conv2d_498[0][0]']
#  atchNormalization)
#
#  activation_498 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_498[0][0
#  )                                                                  ]']
#
#  conv2d_496 (Conv2D)         (None, 12, 12, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_499 (Conv2D)         (None, 12, 12, 96)           82944     ['activation_498[0][0]']
#
#  batch_normalization_496 (B  (None, 12, 12, 384)          1152      ['conv2d_496[0][0]']
#  atchNormalization)
#
#  batch_normalization_499 (B  (None, 12, 12, 96)           288       ['conv2d_499[0][0]']
#  atchNormalization)
#
#  activation_496 (Activation  (None, 12, 12, 384)          0         ['batch_normalization_496[0][0
#  )                                                                  ]']
#
#  activation_499 (Activation  (None, 12, 12, 96)           0         ['batch_normalization_499[0][0
#  )                                                                  ]']
#
#  max_pooling2d_22 (MaxPooli  (None, 12, 12, 288)          0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 12, 12, 768)          0         ['activation_496[0][0]',
#                                                                      'activation_499[0][0]',
#                                                                      'max_pooling2d_22[0][0]']
#
#  conv2d_504 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_504 (B  (None, 12, 12, 128)          384       ['conv2d_504[0][0]']
#  atchNormalization)
#
#  activation_504 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_504[0][0
#  )                                                                  ]']
#
#  conv2d_505 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_504[0][0]']
#
#  batch_normalization_505 (B  (None, 12, 12, 128)          384       ['conv2d_505[0][0]']
#  atchNormalization)
#
#  activation_505 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_505[0][0
#  )                                                                  ]']
#
#  conv2d_501 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_506 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_505[0][0]']
#
#  batch_normalization_501 (B  (None, 12, 12, 128)          384       ['conv2d_501[0][0]']
#  atchNormalization)
#
#  batch_normalization_506 (B  (None, 12, 12, 128)          384       ['conv2d_506[0][0]']
#  atchNormalization)
#
#  activation_501 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_501[0][0
#  )                                                                  ]']
#
#  activation_506 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_506[0][0
#  )                                                                  ]']
#
#  conv2d_502 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_501[0][0]']
#
#  conv2d_507 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_506[0][0]']
#
#  batch_normalization_502 (B  (None, 12, 12, 128)          384       ['conv2d_502[0][0]']
#  atchNormalization)
#
#  batch_normalization_507 (B  (None, 12, 12, 128)          384       ['conv2d_507[0][0]']
#  atchNormalization)
#
#  activation_502 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_502[0][0
#  )                                                                  ]']
#
#  activation_507 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_507[0][0
#  )                                                                  ]']
#
#  average_pooling2d_48 (Aver  (None, 12, 12, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_500 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_503 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_502[0][0]']
#
#  conv2d_508 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_507[0][0]']
#
#  conv2d_509 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_48[0][0]']
#
#  batch_normalization_500 (B  (None, 12, 12, 192)          576       ['conv2d_500[0][0]']
#  atchNormalization)
#
#  batch_normalization_503 (B  (None, 12, 12, 192)          576       ['conv2d_503[0][0]']
#  atchNormalization)
#
#  batch_normalization_508 (B  (None, 12, 12, 192)          576       ['conv2d_508[0][0]']
#  atchNormalization)
#
#  batch_normalization_509 (B  (None, 12, 12, 192)          576       ['conv2d_509[0][0]']
#  atchNormalization)
#
#  activation_500 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_500[0][0
#  )                                                                  ]']
#
#  activation_503 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_503[0][0
#  )                                                                  ]']
#
#  activation_508 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_508[0][0
#  )                                                                  ]']
#
#  activation_509 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_509[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 12, 12, 768)          0         ['activation_500[0][0]',
#                                                                      'activation_503[0][0]',
#                                                                      'activation_508[0][0]',
#                                                                      'activation_509[0][0]']
#
#  conv2d_514 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_514 (B  (None, 12, 12, 160)          480       ['conv2d_514[0][0]']
#  atchNormalization)
#
#  activation_514 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_514[0][0
#  )                                                                  ]']
#
#  conv2d_515 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_514[0][0]']
#
#  batch_normalization_515 (B  (None, 12, 12, 160)          480       ['conv2d_515[0][0]']
#  atchNormalization)
#
#  activation_515 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_515[0][0
#  )                                                                  ]']
#
#  conv2d_511 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_516 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_515[0][0]']
#
#  batch_normalization_511 (B  (None, 12, 12, 160)          480       ['conv2d_511[0][0]']
#  atchNormalization)
#
#  batch_normalization_516 (B  (None, 12, 12, 160)          480       ['conv2d_516[0][0]']
#  atchNormalization)
#
#  activation_511 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_511[0][0
#  )                                                                  ]']
#
#  activation_516 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_516[0][0
#  )                                                                  ]']
#
#  conv2d_512 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_511[0][0]']
#
#  conv2d_517 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_516[0][0]']
#
#  batch_normalization_512 (B  (None, 12, 12, 160)          480       ['conv2d_512[0][0]']
#  atchNormalization)
#
#  batch_normalization_517 (B  (None, 12, 12, 160)          480       ['conv2d_517[0][0]']
#  atchNormalization)
#
#  activation_512 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_512[0][0
#  )                                                                  ]']
#
#  activation_517 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_517[0][0
#  )                                                                  ]']
#
#  average_pooling2d_49 (Aver  (None, 12, 12, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_510 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_513 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_512[0][0]']
#
#  conv2d_518 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_517[0][0]']
#
#  conv2d_519 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_49[0][0]']
#
#  batch_normalization_510 (B  (None, 12, 12, 192)          576       ['conv2d_510[0][0]']
#  atchNormalization)
#
#  batch_normalization_513 (B  (None, 12, 12, 192)          576       ['conv2d_513[0][0]']
#  atchNormalization)
#
#  batch_normalization_518 (B  (None, 12, 12, 192)          576       ['conv2d_518[0][0]']
#  atchNormalization)
#
#  batch_normalization_519 (B  (None, 12, 12, 192)          576       ['conv2d_519[0][0]']
#  atchNormalization)
#
#  activation_510 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_510[0][0
#  )                                                                  ]']
#
#  activation_513 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_513[0][0
#  )                                                                  ]']
#
#  activation_518 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_518[0][0
#  )                                                                  ]']
#
#  activation_519 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_519[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 12, 12, 768)          0         ['activation_510[0][0]',
#                                                                      'activation_513[0][0]',
#                                                                      'activation_518[0][0]',
#                                                                      'activation_519[0][0]']
#
#  conv2d_524 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_524 (B  (None, 12, 12, 160)          480       ['conv2d_524[0][0]']
#  atchNormalization)
#
#  activation_524 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_524[0][0
#  )                                                                  ]']
#
#  conv2d_525 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_524[0][0]']
#
#  batch_normalization_525 (B  (None, 12, 12, 160)          480       ['conv2d_525[0][0]']
#  atchNormalization)
#
#  activation_525 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_525[0][0
#  )                                                                  ]']
#
#  conv2d_521 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_526 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_525[0][0]']
#
#  batch_normalization_521 (B  (None, 12, 12, 160)          480       ['conv2d_521[0][0]']
#  atchNormalization)
#
#  batch_normalization_526 (B  (None, 12, 12, 160)          480       ['conv2d_526[0][0]']
#  atchNormalization)
#
#  activation_521 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_521[0][0
#  )                                                                  ]']
#
#  activation_526 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_526[0][0
#  )                                                                  ]']
#
#  conv2d_522 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_521[0][0]']
#
#  conv2d_527 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_526[0][0]']
#
#  batch_normalization_522 (B  (None, 12, 12, 160)          480       ['conv2d_522[0][0]']
#  atchNormalization)
#
#  batch_normalization_527 (B  (None, 12, 12, 160)          480       ['conv2d_527[0][0]']
#  atchNormalization)
#
#  activation_522 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_522[0][0
#  )                                                                  ]']
#
#  activation_527 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_527[0][0
#  )                                                                  ]']
#
#  average_pooling2d_50 (Aver  (None, 12, 12, 768)          0         ['mixed5[0][0]']
#  agePooling2D)
#
#  conv2d_520 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed5[0][0]']
#
#  conv2d_523 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_522[0][0]']
#
#  conv2d_528 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_527[0][0]']
#
#  conv2d_529 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_50[0][0]']
#
#  batch_normalization_520 (B  (None, 12, 12, 192)          576       ['conv2d_520[0][0]']
#  atchNormalization)
#
#  batch_normalization_523 (B  (None, 12, 12, 192)          576       ['conv2d_523[0][0]']
#  atchNormalization)
#
#  batch_normalization_528 (B  (None, 12, 12, 192)          576       ['conv2d_528[0][0]']
#  atchNormalization)
#
#  batch_normalization_529 (B  (None, 12, 12, 192)          576       ['conv2d_529[0][0]']
#  atchNormalization)
#
#  activation_520 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_520[0][0
#  )                                                                  ]']
#
#  activation_523 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_523[0][0
#  )                                                                  ]']
#
#  activation_528 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_528[0][0
#  )                                                                  ]']
#
#  activation_529 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_529[0][0
#  )                                                                  ]']
#
#  mixed6 (Concatenate)        (None, 12, 12, 768)          0         ['activation_520[0][0]',
#                                                                      'activation_523[0][0]',
#                                                                      'activation_528[0][0]',
#                                                                      'activation_529[0][0]']
#
#  conv2d_534 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed6[0][0]']
#
#  batch_normalization_534 (B  (None, 12, 12, 192)          576       ['conv2d_534[0][0]']
#  atchNormalization)
#
#  activation_534 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_534[0][0
#  )                                                                  ]']
#
#  conv2d_535 (Conv2D)         (None, 12, 12, 192)          258048    ['activation_534[0][0]']
#
#  batch_normalization_535 (B  (None, 12, 12, 192)          576       ['conv2d_535[0][0]']
#  atchNormalization)
#
#  activation_535 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_535[0][0
#  )                                                                  ]']
#
#  conv2d_531 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed6[0][0]']
#
#  conv2d_536 (Conv2D)         (None, 12, 12, 192)          258048    ['activation_535[0][0]']
#
#  batch_normalization_531 (B  (None, 12, 12, 192)          576       ['conv2d_531[0][0]']
#  atchNormalization)
#
#  batch_normalization_536 (B  (None, 12, 12, 192)          576       ['conv2d_536[0][0]']
#  atchNormalization)
#
#  activation_531 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_531[0][0
#  )                                                                  ]']
#
#  activation_536 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_536[0][0
#  )                                                                  ]']
#
#  conv2d_532 (Conv2D)         (None, 12, 12, 192)          258048    ['activation_531[0][0]']
#
#  conv2d_537 (Conv2D)         (None, 12, 12, 192)          258048    ['activation_536[0][0]']
#
#  batch_normalization_532 (B  (None, 12, 12, 192)          576       ['conv2d_532[0][0]']
#  atchNormalization)
#
#  batch_normalization_537 (B  (None, 12, 12, 192)          576       ['conv2d_537[0][0]']
#  atchNormalization)
#
#  activation_532 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_532[0][0
#  )                                                                  ]']
#
#  activation_537 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_537[0][0
#  )                                                                  ]']
#
#  average_pooling2d_51 (Aver  (None, 12, 12, 768)          0         ['mixed6[0][0]']
#  agePooling2D)
#
#  conv2d_530 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed6[0][0]']
#
#  conv2d_533 (Conv2D)         (None, 12, 12, 192)          258048    ['activation_532[0][0]']
#
#  conv2d_538 (Conv2D)         (None, 12, 12, 192)          258048    ['activation_537[0][0]']
#
#  conv2d_539 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_51[0][0]']
#
#  batch_normalization_530 (B  (None, 12, 12, 192)          576       ['conv2d_530[0][0]']
#  atchNormalization)
#
#  batch_normalization_533 (B  (None, 12, 12, 192)          576       ['conv2d_533[0][0]']
#  atchNormalization)
#
#  batch_normalization_538 (B  (None, 12, 12, 192)          576       ['conv2d_538[0][0]']
#  atchNormalization)
#
#  batch_normalization_539 (B  (None, 12, 12, 192)          576       ['conv2d_539[0][0]']
#  atchNormalization)
#
#  activation_530 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_530[0][0
#  )                                                                  ]']
#
#  activation_533 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_533[0][0
#  )                                                                  ]']
#
#  activation_538 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_538[0][0
#  )                                                                  ]']
#
#  activation_539 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_539[0][0
#  )                                                                  ]']
#
#  mixed7 (Concatenate)        (None, 12, 12, 768)          0         ['activation_530[0][0]',
#                                                                      'activation_533[0][0]',
#                                                                      'activation_538[0][0]',
#                                                                      'activation_539[0][0]']
#
#  flatten_80 (Flatten)        (None, 110592)               0         ['mixed7[0][0]']
#
#  dense_197 (Dense)           (None, 128)                  1415590   ['flatten_80[0][0]']
#                                                           4
#
#  dense_198 (Dense)           (None, 1)                    129       ['dense_197[0][0]']
#
# ==================================================================================================
# Total params: 23131297 (88.24 MB)
# Trainable params: 14156033 (54.00 MB)
# Non-trainable params: 8975264 (34.24 MB)
# __________________________________________________________________________________________________

# %%
model.predict()
